# %%
from matplotlib import pyplot as plt, patches
import numpy as np
from ipywidgets import widgets, interact
from IPython.display import display
import csidata as cid
import pandas as pd
from os.path import basename, splitext, exists

# %%
frame_timestamps = None
# Sample data
# data = sio.loadmat('../DeepSeg/01Data_PreProcess/Data_CsiAmplitudeCut/philipp/55philipp_uc_d.mat')['data_']
# data = csidata.load('DeepSeg/01Data_PreProcess/Data_CsiAmplitudeCut/philipp/55philipp_uc_d.mat', csidata.FileFormat.MAT_7_3)
filename = 'recordings/csi/2024-09-27T13-08-02_480164.raw'
filename = 'analysis/outside_recording/2024-09-30T19-55-50_056812_seq-iw.raw'
filename = 'recordings/csi/2024-10-10T17-01-57_429901_ph.raw'
filename = 'recordings/csi/2024-10-11T13-51-55_693628.raw'
filename = 'record/prod_data/csi/user1/2024-10-11T16-53-18-669897_seq-iw.joblib'
# filename = 'recordings/csi/2024-10-15T17-33-03-720294.raw'
# filename = 'recordings/csi/2024-10-16T17-35-42-664895.raw'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-23-58-202160_seq-sd.joblib'
# filename = 'recordings/csi/2024-10-17T17-03-04-151691.raw'

# filename = 'record/prod_data/csi/user1/2024-10-11T17-02-22-296947_seq-ph.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-04-18-741718_seq-ph.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-05-49-170291_seq-ph.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-06-48-096612_seq-ph.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-09-06-000850_seq-ph.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-11-48-279807_seq-ph.joblib'

# filename = 'record/prod_data/csi/user1/2024-10-11T17-14-07-312598_seq-rp.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-16-06-407371_seq-rp.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-17-06-928945_seq-rp.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-18-38-301779_seq-rp.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-19-40-755138_seq-rp.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-20-49-594629_seq-rp.joblib'

# filename = 'record/prod_data/csi/user1/2024-10-11T17-24-50-860221_seq-sd.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-27-50-910991_seq-sd.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-28-59-804945_seq-sd.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-30-24-686743_seq-sd.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-31-45-171551_seq-sd.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-32-50-910010_seq-sd.joblib'

# filename = 'record/prod_data/csi/user1/2024-10-11T17-46-37-311054_seq-wd.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-48-01-357582_seq-wd.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-49-22-699238_seq-wd.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-50-36-100037_seq-wd.joblib'
# filename = 'record/prod_data/csi/user1/2024-10-11T17-51-49-659091_seq-wd.joblib'
filename = 'record/prod_data/csi/user1/2024-10-11T17-53-07-740347_seq-wd.raw'


label_save_file = 'record/prod_data/user1.csv'

# %%
data = cid.load(filename)
csi = data.csi
csi.shape

input_reduction = 20
sel = np.index_exp[::input_reduction, 2, 2, 0]

csiTrace = csi[sel]
csiTrace.shape
# Out:
# (2679,)

# %%
def set_csi_trace(rx_idx, tx_idx, subcarrier_idx):
    global csiTrace
    csiTrace = csi[::input_reduction, rx_idx, tx_idx, subcarrier_idx]
    # plot_csi_trace(csiTrace)

# %%
import subprocess
import threading

img_thread: threading.Thread = None
img_subprocess: subprocess.Popen = None
prev_frame_idx = -1
video_path = None
image = None
tmp_file = None

def display_video_frame(frame_idx):
    global img_thread, img_subprocess, prev_frame_idx, tmp_file
    # print(f'Requesting frame {frame_idx}')
    if img_thread is not None and img_thread.is_alive():
        if prev_frame_idx == frame_idx:
            print('Same frame being requested, wait for existing thread to finish')
            return
        
        print('Stopping previous subprocess')
        img_subprocess.kill()
    else:
        if prev_frame_idx == frame_idx:
            print('Frame already displayed')
            return
    
    # print('Creating new thread')
    img_thread = threading.Thread(target=get_video_frame, args=(frame_idx,))
    img_thread.start()
    prev_frame_idx = frame_idx


def get_video_frame(frame_idx):
    global image, img_subprocess, tmp_file

    print(f'FFMPEG get frame {frame_idx}')
    img_subprocess = subprocess.Popen(fr'ffmpeg -v error -f rawvideo -pix_fmt yuv422p -s 1280x720 -framerate 60 -i {tmp_file} -vf select=eq(n\,{frame_idx}) -vframes 1 -f image2 -c:v png pipe:'.split(), 
                                  stdout=subprocess.PIPE, stdin=subprocess.PIPE, stderr=subprocess.PIPE)
    # print('FFMPEG process started')
    out, err = img_subprocess.communicate()
    if img_subprocess.returncode != 0:
        print(f'Error getting frame {frame_idx}')
        print(err)
        return
    
    # print(f'Frame {frame_idx} received')
    
    image.value = out
    # print(f'Set image for frame {frame_idx}')

# %%
import datetime

def getNearestIdx(array, value):
    return (np.abs(array - value)).argmin()

def getVideoFrameMatchingCsiPosition(csi_idx: int):
    # limit csi_idx to the range of the csi data
    csi_idx = np.clip(csi_idx, 0, csi.shape[0]-1)
    csi_ts = data.status[::input_reduction.value][csi_idx].tstamp
    print(csi_ts)

    if frame_timestamps is not None:
        frame_idx = getNearestIdx(frame_timestamps, csi_ts)
    else:
        start_time = basename(filename).split('_')[0]
        start_time = datetime.datetime.strptime(start_time, '%Y-%m-%dT%H-%M-%S-%f')

        # video_start_time = start_time + datetime.timedelta(milliseconds=660) # 0.66s delay 
        video_start_time = start_time + datetime.timedelta(milliseconds=660+180) # 0.66s delay 

        csi_dt = datetime.datetime.fromtimestamp(csi_ts/1e6)

        # video frame rate is 60 fps
        # frame_idx = (csi_dt - video_start_time).total_seconds() * 60
        frame_idx = (csi_dt - video_start_time).total_seconds() * 60.35
        max_idx = csi.shape[0] - 1 # TODO get from video
        frame_idx = np.clip(int(frame_idx), 0, max_idx)

    display_video_frame(frame_idx)
    print(frame_idx)

# %%
# getVideoFrameMatchingCsiPosition(30, 'record/prod_data/video/user1/2024-10-11T16-53-18-669897_seq-iw.mp4')

# %%
class Notifier():
    def __init__(self):
        self.func = []

    def register(self, func):
        self.func.append(func)

    def notify(self):
        for f in self.func:
            f()

# %%
from typing import NamedTuple

import pandas as pd

from csidata.types import Activity, CSI_Result

class SegmentListEntry:
    def __init__(self, segment_list_manager, segment_bounds: tuple[int, int], segment_label: str, segment_id: int, segment_type_options: list[tuple[str, int]]):
        self.segment_bounds = segment_bounds
        self.segment_id = segment_id
        self.segment_type = widgets.Dropdown(options=segment_type_options, value=segment_type_options[0][1], layout=widgets.Layout(width='auto'))
        self.item = widgets.HBox()
        self.id_label = widgets.Label(str(segment_id))
        self.label = widgets.Label(segment_label)
        self.segment_list_manager = segment_list_manager

        space = widgets.HTML("<span style='margin-right: 1em;'></span>")

        move_down_button = widgets.Button(description='⬇️', layout=widgets.Layout(width='auto'))
        move_up_button = widgets.Button(description='⬆️', layout=widgets.Layout(width='auto'))
        remove_button = widgets.Button(description='X', layout=widgets.Layout(width='auto'))

        remove_button.on_click(lambda _: self.segment_list_manager.removeSegment(self))
        move_down_button.on_click(lambda _: self.segment_list_manager.move_down(self))
        move_up_button.on_click(lambda _: self.segment_list_manager.move_up(self))

        self.item.children = [self.id_label, space, self.label, self.segment_type, move_down_button, move_up_button, remove_button]

    def update_id(self, new_id: int):
        self.segment_id = new_id
        self.id_label.value = str(new_id)



class Segment(NamedTuple):
    start: int
    end: int
    type: Activity
    

class SegmentListManager:
    def __init__(self, segments: list[Segment], segment_notifier: Notifier, digits_padding: int, csi_result: CSI_Result) -> None:
        self.segment_notifier = segment_notifier
        self.segment_notifier.register(self.update)
        self.segment_list_items: list[SegmentListEntry] = []
        self.segments = segments
        self.csi_result = csi_result
        self.digits_padding = digits_padding
        self.vbox = widgets.VBox(layout=widgets.Layout(width='350px', min_width='300px'))
        
    def update(self) -> None:
        def segment_equals_entry(segment_bounds: tuple[int, int], entry: SegmentListEntry) -> bool:
            return entry.segment_bounds[0] == segment_bounds[0] and entry.segment_bounds[1] == segment_bounds[1]

        if len(self.segments) == len(self.segment_list_items): # two segments have been swapped, update list items
            for idx, s in enumerate(self.segments):
                if not segment_equals_entry(s, self.segment_list_items[idx]):
                    self.segment_list_items[idx].item.close()
                    self.segment_list_items[idx] = self.createSegmentEntry(s, idx)
            
        elif len(self.segments) > len(self.segment_list_items): # segment has been added
            missing_item = [s for s in self.segments if not any(segment_equals_entry(s, e) for e in self.segment_list_items)] [0]
            self.segment_list_items.append(self.createSegmentEntry(missing_item, self.segments.index(missing_item)))

        elif len(self.segments) < len(self.segment_list_items): # segment has been removed
            excess_item = [e for e in self.segment_list_items if not any(segment_equals_entry(s, e) for s in self.segments)] [0]
            self.segment_list_items.remove(excess_item)
            excess_item.item.close()

        # self.segment_list_items = [self.createSegmentEntry(segment) for segment in self.segments]
        self.vbox.children = [e.item for e in self.segment_list_items]
        

    def createSegmentEntry(self, segment_bounds: tuple[int, int], segment_id) -> None:
        label = f"({segment_bounds[0]:>0{self.digits_padding}}, {segment_bounds[1]:>0{self.digits_padding}})"

        allowed_activities: list[Activity]
        if self.csi_result.activity:
            allowed_activities = [self.csi_result.activity]
        elif self.csi_result.sequence:
            allowed_activities = list(self.csi_result.sequence.value)
        else:
            allowed_activities = list(Activity)

        segment_type_options = [(a.name, a.value) for a in allowed_activities]

        return SegmentListEntry(self, segment_bounds, label, segment_id, segment_type_options)

    def removeSegment(self, item) -> None:
        idx = self.segment_list_items.index(item)
        self.segments.pop(idx)
        self.segment_notifier.notify()

    def move_up(self, item) -> None:
        idx = self.segment_list_items.index(item)
        if idx > 0:
            self.segments[idx], self.segments[idx - 1] = self.segments[idx - 1], self.segments[idx]
            self.segment_list_items[idx], self.segment_list_items[idx - 1] = self.segment_list_items[idx - 1], self.segment_list_items[idx]
            self.segment_list_items[idx].update_id(idx)
            self.segment_list_items[idx - 1].update_id(idx - 1)
            self.segment_notifier.notify()

    
    def move_down(self, item) -> None:
        idx = self.segment_list_items.index(item)
        if idx < len(self.segments) - 1:
            self.segments[idx], self.segments[idx + 1] = self.segments[idx + 1], self.segments[idx]
            self.segment_list_items[idx], self.segment_list_items[idx + 1] = self.segment_list_items[idx + 1], self.segment_list_items[idx]
            self.segment_list_items[idx].update_id(idx)
            self.segment_list_items[idx + 1].update_id(idx + 1)
            self.segment_notifier.notify()

    
    def getListBox(self):
        return self.vbox
    
    def save_segments(self):
        segs = []
        for seg in self.segment_list_items:
            segs.append(Segment(seg.segment_bounds[0], seg.segment_bounds[1], Activity(seg.segment_type.value)))
        # print(segs)

        columns=['fileNumber', 'activityNumber', 'startPoint', 'endPoint', 'fileName', 'activityCategory']
        try:
            stored_seg = pd.read_csv(label_save_file)
            print(stored_seg.columns)
        except FileNotFoundError:
            stored_seg = pd.DataFrame(columns=columns)

        file_number = stored_seg['fileNumber'].max() + 1 if not stored_seg.empty else 1 # 1-based indexing
        
        recording_name = splitext(basename(filename))[0]

        # if file already has segments, delete to replace them with the current ones
        stored_seg = stored_seg[stored_seg['fileName'] != recording_name]

        added_segments_list = [(file_number, idx, s.start, s.end, recording_name, sli.segment_type.value) for idx, (s, sli) in enumerate(zip(self.segments, self.segment_list_items))]
        added_segments = pd.DataFrame(added_segments_list, columns=columns)
        print(added_segments)
        added_segments['activityNumber'] += 1 # 1-based indexing
        added_segments['activityCategory'] += 1 # 1-based indexing
        print(added_segments)

        pd.concat([stored_seg, added_segments], ignore_index=True).to_csv(label_save_file, index=False)

# %%
class CSIPlot:
    def __init__(self, csiTrace: np.ndarray, segments: list[Segment], segment_notifier: Notifier) -> None:
        self.notifier = segment_notifier
        self.notifier.register(self.redraw_segments)
        self.csiTrace = csiTrace
        self.output = widgets.Output()
        self.segment_selection_start = None
        self.cursorLine = None
        self.segmentStartLine = None

        self.segments = segments

        self.segmentSelectionSpan = None
        self.segmentSpans: list[patches.Polygon] = []
        self.segment_labels: list[plt.Text] = []

        self.margin = 0.1

        # self.background = None
        # self.ln = None

        with self.output:
            with plt.ioff():
                self.fig, self.ax = plt.subplots()
            self.fig: plt.Figure
            self.ax: plt.Axes

            self.fig.canvas.header_visible = False
            # self.fig.canvas.toolbar_visible = 'fade-in-fade-out'
            self.fig.canvas.toolbar_visible = False
            self.fig.canvas.footer_visible = False
            self.fig.canvas.capture_scroll = True
    
            (self.ln,) = self.ax.plot(csiTrace)
            # (self.ln,) = self.ax.plot(csiTrace, animated=True)
            # plt.show(block=False)
            # plt.pause(0.1)

            # self.background = self.fig.canvas.copy_from_bbox(self.fig.bbox)
            # self.ax.draw_artist(self.ln)
            # self.fig.canvas.blit(self.fig.bbox)

            self.cursorLine = self.ax.axvline(0, color='r', alpha=0.5)

            self.segmentStartLine = self.ax.axvline(0, color='g', alpha=0.5)
            self.segmentStartLine.set_visible(False)
            
            self.segmentSelectionSpan = self.ax.axvspan(0, 0, color='orange', alpha=0.2)
            self.segmentSelectionSpan.set_visible(False)
            
        self.fig.canvas.mpl_connect('scroll_event', self.handle_scroll)
            
    def start_selection(self, xpos):
        self.segment_selection_start = xpos
        self.segmentStartLine.set_xdata([xpos])
        self.segmentStartLine.set_visible(True)
        self.segmentSelectionSpan.set_xy([xpos, 0])
        self.segmentSelectionSpan.set_width(0)
        self.segmentSelectionSpan.set_visible(True)
        with self.output:
            self.ax.draw_artist(self.segmentStartLine)
            self.ax.draw_artist(self.segmentSelectionSpan)
            self.fig.canvas.draw_idle()        
    
    def end_selection(self, xpos):
        if not self.segment_selection_start:
            return

        self.segments.append(Segment(self.segment_selection_start, xpos, None))
        self.segment_selection_start = None
        self.segmentStartLine.set_visible(False)
        self.segmentSelectionSpan.set_visible(False)
        with self.output:
            self.redraw_segments()
            self.fig.canvas.draw_idle()        
        self.notifier.notify()
    
    def abort_selection(self):
        self.segment_selection_start = None
        self.segmentStartLine.set_visible(False)
        self.segmentSelectionSpan.set_visible(False)

        with self.output:
            self.fig.canvas.draw_idle()    

    def handle_plot_click(self, xpos):
        if xpos < 0 or xpos >= len(self.csiTrace):
            return
        
        if self.segment_selection_start:
            self.end_selection(xpos)
        else:
            self.start_selection(xpos)

    def draw_cursor(self,xpos):
        self.cursorLine.set_xdata([xpos])
        with self.output:
            self.fig.canvas.draw_idle()

    def draw_current_segment_selection_span(self, cursorPosition):
        if self.segment_selection_start:
            self.segmentSelectionSpan.set_xy([self.segment_selection_start, 0])
            self.segmentSelectionSpan.set_width(cursorPosition - self.segment_selection_start)
            self.ax.draw_artist(self.segmentSelectionSpan)
            with self.output:
                self.fig.canvas.draw_idle()
    def redraw_segments(self):
        for segment in self.segmentSpans:
            segment.remove()
        
        self.segmentSpans.clear()
        
        for segment in self.segments:
            self.segmentSpans.append(self.ax.axvspan(segment.start, segment.end, color='yellow', alpha=0.2))
        
        self.redraw_segment_labels()
        with self.output:
            self.fig.canvas.draw_idle()
    
    def redraw_segment_labels(self):
        for label in self.segment_labels:
            label.remove()

        self.segment_labels.clear()
        visible_yregion = self.ax.get_ylim()
        
        for idx, segment in enumerate(self.segments):
            self.segment_labels.append(self.ax.text((segment.start + segment.end)/2, visible_yregion[1], str(idx), horizontalalignment='center', verticalalignment='top'))

    def redraw(self):
        with self.output:
            self.fig.canvas.draw_idle()

    def move_cursor(self, xpos):
        global video_raw, image, cap, tmp_file
        xpos = int(xpos)
        # display_video_frame(tmp_file, xpos)
        getVideoFrameMatchingCsiPosition(xpos)

        # display_frame_mp4(cap, xpos)
        self.draw_cursor(xpos)
        self.draw_current_segment_selection_span(xpos)
        # self.fig.canvas.flush_events()

    def handle_scroll(self, event):
        if event.inaxes != self.ax: # ignore scroll event outside axis
            return
        zoom_factor = 0.1

        cur_xlim = self.ax.get_xlim()

        xdata = event.xdata

        if event.button == 'up':  # Zoom in
            new_xlim = [xdata - (xdata-cur_xlim[0])*(1-zoom_factor), xdata + (cur_xlim[1]-xdata)*(1-zoom_factor)]
            self.ax.set_xlim(new_xlim)
        elif event.button == 'down':  # Zoom out
            new_xlim = [xdata - (xdata-cur_xlim[0])*(1+zoom_factor), xdata + (cur_xlim[1]-xdata)*(1+zoom_factor)]
            self.ax.set_xlim(new_xlim)

        # limit x range to the data range to avoid out of bounds when determining min/max for this region
        x_idx_in_view = [max(round(new_xlim[0]), 0), 
                         min(round(new_xlim[1]), len(self.csiTrace))]

        new_ylim = [self.csiTrace[x_idx_in_view[0]:x_idx_in_view[1]].min(), self.csiTrace[x_idx_in_view[0]:x_idx_in_view[1]].max()]

        self.ax.set_ylim([new_ylim[0] + new_ylim[0] * self.margin, new_ylim[1] + new_ylim[1] * self.margin])

        self.redraw_segment_labels()
        self.fig.canvas.draw_idle()  # Redraw the figure to update the plot

# %%
# %matplotlib widget
segments: list[Segment] = []

segment_notifier = Notifier()
plot = CSIPlot(csiTrace, segments, segment_notifier)
segment_manager = SegmentListManager(segments, segment_notifier, len(str(csiTrace.shape[0])), data)

index_slider = widgets.IntSlider(min=0, max=csiTrace.shape[0] -1, step=10, value=0)
interactiveDings = widgets.interactive(plot.move_cursor, xpos=index_slider)

mark_button = widgets.Button(description='Mark')
unmark_button = widgets.Button(description='Unmark')
mark_button.on_click(lambda _: plot.handle_plot_click(index_slider.value))
unmark_button.on_click(lambda _: plot.abort_selection())

controls_hbox = widgets.HBox([mark_button, unmark_button])

save_button = widgets.Button(description='Save')
save_button.on_click(lambda _: segment_manager.save_segments())
# save_button.layout.width = '100%'    

def handle_segment_click(x):
    global segment_manager

    x_idx = round(x)
    plot.handle_plot_click(x_idx)

plot.fig.canvas.mpl_connect('button_press_event', lambda event: handle_segment_click(round(event.xdata)) if event.inaxes == plot.ax else None)
plot.fig.canvas.mpl_connect('motion_notify_event', lambda event: plot.move_cursor(round(event.xdata)) if event.inaxes == plot.ax else None)

image = widgets.Image()
img_width = 500
image.layout = widgets.Layout(width=f"{img_width}px", height=f"{img_width * 9/16}px", top='50%')

hbox_main_content = widgets.HBox([segment_manager.getListBox(), plot.fig.canvas, image])
hbox_main_content.layout.width = '100%'
plot.fig.canvas.layout.width = 'auto'

# set the hbox border color to red
# hbox_segments_plot.layout.border = '1px solid red'

display(hbox_main_content)


# display(interactiveDings)
display(controls_hbox)
display(save_button)

input_rx = widgets.BoundedIntText(description='rx', value=0, min=0, max=csi.shape[1]-1)
input_tx = widgets.BoundedIntText(description='tx', value=0, min=0, max=csi.shape[2]-1)
input_sc = widgets.BoundedIntText(description='sc', value=0, min=0, max=csi.shape[3]-1)
input_reduction = widgets.BoundedIntText(description='red', value=20, min=1, max=csi.shape[0])
confirm_button = widgets.Button(description='Confirm')

csi_selection = widgets.HBox([input_rx, input_tx, input_sc, input_reduction, confirm_button], layout=widgets.Layout(width='auto'))

def on_confirm_button_clicked(_):
    global csiTrace
    print(f'rx: {input_rx.value}, tx: {input_tx.value}, sc: {input_sc.value}, red: {input_reduction.value}')
    csiTrace = csi[::input_reduction.value, input_rx.value, input_tx.value, input_sc.value]

    plot.ln.remove()

    plot.csiTrace = csiTrace
    # plot.ax.clear()
    (plot.ln,) = plot.ax.plot(csiTrace)
    plot.redraw()
    plot.redraw_segments()
    plot.redraw_segment_labels()

confirm_button.on_click(on_confirm_button_clicked)

display(csi_selection)

# filename = "record/recordings/2024-09-04T13-11-58+02-00.mp4"
filename_stem = splitext(basename(filename))[0]

# video_path = f"recordings/video/{filename_stem}.mp4"
video_path = f"record/prod_data/video/user1/{filename_stem}.mp4"
tmp_folder = "recordings/tmp"
tmp_file = f"{tmp_folder}/{filename_stem}.yuv"

if exists(splitext(video_path)[0] + '.txt'):
    with open(splitext(video_path)[0] + '.txt') as f:
            frames_ts = f.read().splitlines()[1:] # skip first line as it is a comment
            frames_ts = map(int, frames_ts)
    frame_timestamps = np.array(list(frames_ts))
    frame_timestamps = frame_timestamps * 1e3 # convert from ms to us presicion to match csi data
else:
    frame_timestamps = None

# check if tmp video file exists
if not exists(tmp_file):
    # convert video to yuv format
    video_raw =  subprocess.run(f"ffmpeg -y -v error -i {video_path} -f rawvideo -pix_fmt yuv422p -framerate 60 {tmp_file}".split(), stdout=subprocess.PIPE, check=True)
# cap = cv2.VideoCapture('/home/felix/Documents/uni/BaProj/bachelorproject/record/recordings/2024-09-04T13-11-58+02-00.mp4')

# get_video_frame(video_raw.stdout, 0)
getVideoFrameMatchingCsiPosition(0)
# Out:
# HBox(children=(VBox(layout=Layout(min_width='300px', width='350px')), Canvas(capture_scroll=True, footer_visib…
# HBox(children=(Button(description='Mark', style=ButtonStyle()), Button(description='Unmark', style=ButtonStyle…
# Button(description='Save', style=ButtonStyle())
# HBox(children=(BoundedIntText(value=0, description='rx', max=2), BoundedIntText(value=0, description='tx', max…
# 1728661987995028
# FFMPEG get frame 0
# 0
# 1728662007835150
# 1162
# FFMPEG get frame 1162
# 1728662003919311
# Stopping previous subprocess
# 925
# FFMPEG get frame 925
# Error getting frame 1162
# b''
# 1728662002405472
# Stopping previous subprocess
# 834
# FFMPEG get frame 834
# 1728662000466509
# Stopping previous subprocess
# 717
# FFMPEG get frame 717
# Error getting frame 834
# b''
# Error getting frame 925
# b''
# 1728662000285472
# Stopping previous subprocess
# 706
# FFMPEG get frame 706
# Error getting frame 717
# b''
# 1728662000195234
# Stopping previous subprocess
# 700
# FFMPEG get frame 700
# Error getting frame 706
# b''
# 1728662000285472
# Stopping previous subprocess
# 706
# FFMPEG get frame 706
# Error getting frame 700
# b''
# 1728662000104383
# Stopping previous subprocess
# 695
# FFMPEG get frame 695
# 1728661999812529
# Stopping previous subprocess
# 677
# FFMPEG get frame 677
# Error getting frame 695
# b''
# Error getting frame 706
# b''
# 1728661997779359
# Stopping previous subprocess
# 555
# FFMPEG get frame 555
# Error getting frame 677
# b''
# 1728661996667595
# Stopping previous subprocess
# 488
# FFMPEG get frame 488
# 1728661995954978
# Stopping previous subprocess
# 445
# FFMPEG get frame 445
# Error getting frame 555
# b''
# Error getting frame 488
# b''
# 1728661995326388
# Stopping previous subprocess
# 407
# FFMPEG get frame 407
# Error getting frame 445
# b''
# FFMPEG get frame 401
# 1728661995230682
# Stopping previous subprocess
# 401
# Error getting frame 407
# b''
# 1728661995230682
# Same frame being requested, wait for existing thread to finish
# 401
# 1728661994860508
# Stopping previous subprocess
# 379
# FFMPEG get frame 379
# 1728661994656410
# Stopping previous subprocess
# 366
# FFMPEG get frame 366
# Error getting frame 401
# b''
# Error getting frame 379
# b''
# 1728661994481272
# Stopping previous subprocess
# 356
# FFMPEG get frame 356
# Error getting frame 366
# b''
# 1728661993549858
# Stopping previous subprocess
# 299
# FFMPEG get frame 299
# Error getting frame 356
# b''
# 1728661993201728
# Stopping previous subprocess
# 278
# FFMPEG get frame 278
# Error getting frame 299
# b''
# 1728661992657927
# Stopping previous subprocess
# 246
# FFMPEG get frame 246
# Error getting frame 278
# b''
# FFMPEG get frame 201
# 1728661991922545
# Stopping previous subprocess
# 201
# Error getting frame 246
# b''
# 1728661991748214
# Stopping previous subprocess
# 191
# FFMPEG get frame 191
# Error getting frame 201
# b''
# 1728661991028153
# Stopping previous subprocess
# 147
# FFMPEG get frame 147
# Error getting frame 191
# b''
# FFMPEG get frame 141
# 1728661990919180
# Stopping previous subprocess
# 141
# Error getting frame 147
# b''
# 1728661990919180
# Same frame being requested, wait for existing thread to finish
# 141
# 1728661990745577
# Stopping previous subprocess
# 130
# FFMPEG get frame 130
# Error getting frame 141
# b''
# 1728661990745577
# Same frame being requested, wait for existing thread to finish
# 130
# 1728661990658290
# 125
# FFMPEG get frame 125
# 1728661990573192
# Stopping previous subprocess
# 120
# FFMPEG get frame 120
# Error getting frame 125
# b''
# 1728661990486946
# Stopping previous subprocess
# 115
# FFMPEG get frame 115
# Error getting frame 120
# b''
# 1728661990573192
# Stopping previous subprocess
# 120
# FFMPEG get frame 120
# 1728661990658290
# Stopping previous subprocess
# 125
# FFMPEG get frame 125
# Error getting frame 120
# b''
# Error getting frame 115
# b''
# 1728661990919180
# Stopping previous subprocess
# 141
# Error getting frame 125
# b''
# FFMPEG get frame 141
# 1728661991114686
# Stopping previous subprocess
# 152
# FFMPEG get frame 152
# Error getting frame 141
# b''
# FFMPEG get frame 163
# 1728661991289850
# Stopping previous subprocess
# 163
# Error getting frame 152
# b''
# 1728661991289850
# Same frame being requested, wait for existing thread to finish
# 163
# 1728661990919180
# Stopping previous subprocess
# 141
# FFMPEG get frame 141
# 1728661990117692
# Stopping previous subprocess
# 92
# FFMPEG get frame 92
# Error getting frame 163
# b''
# Error getting frame 141
# b''
# 1728661989669280
# Stopping previous subprocess
# 65
# FFMPEG get frame 65
# Error getting frame 92
# b''
# 1728661989036588
# Stopping previous subprocess
# 27
# FFMPEG get frame 27
# Error getting frame 65
# b''
# FFMPEG get frame 5
# 1728661988668217
# Stopping previous subprocess
# 5
# Error getting frame 27
# b''
# 1728661988497299
# Stopping previous subprocess
# 0
# FFMPEG get frame 0
# Error getting frame 5
# b''
# 1728661988412616
# Same frame being requested, wait for existing thread to finish
# 0
# 1728661988412616
# Same frame being requested, wait for existing thread to finish
# 0
# 1728661988309509
# Frame already displayed
# 0
# 1728661988141358
# Frame already displayed
# 0
# 1728661987995028
# Frame already displayed
# 0
# 1728661987995028
# Frame already displayed
# 0
# 1728661987995028
# Frame already displayed
# 0
# 1728661987995028
# Frame already displayed
# 0
# 1728661987995028
# Frame already displayed
# 0
# 1728661987995028
# Frame already displayed
# 0
# 1728661987995028
# Frame already displayed
# 0
# 1728661988162370
# Frame already displayed
# 0
# 1728661988225519
# Frame already displayed
# 0
# 1728661988350482
# Frame already displayed
# 0
# 1728661988350482
# Frame already displayed
# 0
# 1728661988433637
# Frame already displayed
# 0
# 1728661988993371
# 24
# FFMPEG get frame 24
# 1728661989861940
# Stopping previous subprocess
# 77
# FFMPEG get frame 77
# Error getting frame 24
# b''
# 1728661989968982
# Stopping previous subprocess
# 83
# FFMPEG get frame 83
# Error getting frame 77
# b''
# 1728661990291529
# Stopping previous subprocess
# 103
# FFMPEG get frame 103
# Error getting frame 83
# b''
# FFMPEG get frame 124
# 1728661990636892
# Stopping previous subprocess
# 124
# Error getting frame 103
# b''
# 1728661991333165
# Stopping previous subprocess
# 166
# FFMPEG get frame 166
# Error getting frame 124
# b''
# FFMPEG get frame 181
# 1728661991595012
# Stopping previous subprocess
# 181
# Error getting frame 166
# b''
# 1728661991703477
# Stopping previous subprocess
# 188
# FFMPEG get frame 188
# Error getting frame 181
# b''
# 1728661991769874
# Stopping previous subprocess
# 192
# FFMPEG get frame 192
# Error getting frame 188
# b''
# FFMPEG get frame 199
# 1728661991879014
# Stopping previous subprocess
# 199
# Error getting frame 192
# b''
# 1728661991879014
# Same frame being requested, wait for existing thread to finish
# 199
# 1728661991879014
# Same frame being requested, wait for existing thread to finish
# 199
# 1728661991879014
# Same frame being requested, wait for existing thread to finish
# 199
# 1728661991879014
# Same frame being requested, wait for existing thread to finish
# 199
# 1728661991879014
# Frame already displayed
# 199
# 1728661992008252
# 206
# FFMPEG get frame 206
# 1728661992376405
# Stopping previous subprocess
# 229
# FFMPEG get frame 229
# 1728661992506378
# Stopping previous subprocess
# 236
# FFMPEG get frame 236
# Error getting frame 229
# b''
# Error getting frame 206
# b''
# 1728661992527991
# Stopping previous subprocess
# 238
# FFMPEG get frame 238
# Error getting frame 236
# b''
# 1728661992571076
# Stopping previous subprocess
# 240
# FFMPEG get frame 240
# Error getting frame 238
# b''
# FFMPEG get frame 244
# 1728661992636769
# Stopping previous subprocess
# 244
# Error getting frame 240
# b''
# FFMPEG get frame 253
# 1728661992788646
# Stopping previous subprocess
# 253
# Error getting frame 244
# b''
# 1728661992875783
# Stopping previous subprocess
# 259
# FFMPEG get frame 259
# Error getting frame 253
# b''
# FFMPEG get frame 271
# 1728661993072161
# Stopping previous subprocess
# 271
# Error getting frame 259
# b''
# 1728661993288822
# Stopping previous subprocess
# 284
# FFMPEG get frame 284
# Error getting frame 271
# b''
# 1728661993354150
# Stopping previous subprocess
# 288
# FFMPEG get frame 288
# Error getting frame 284
# b''
# 1728661993397402
# 290
# FFMPEG get frame 290
# 1728661993354150
# 288
# FFMPEG get frame 288
# 1728661993288822
# Stopping previous subprocess
# 284
# FFMPEG get frame 284
# Error getting frame 288
# b''
# 1728661993288822
# Same frame being requested, wait for existing thread to finish
# 284
# 1728661993223597
# Stopping previous subprocess
# 280
# FFMPEG get frame 280
# Error getting frame 284
# b''
# FFMPEG get frame 276
# 1728661993158228
# Stopping previous subprocess
# 276
# Error getting frame 280
# b''
# FFMPEG get frame 274
# 1728661993136577
# Stopping previous subprocess
# 274
# Error getting frame 276
# b''
# 1728661993072161
# Stopping previous subprocess
# 271
# FFMPEG get frame 271
# Error getting frame 274
# b''
# FFMPEG get frame 267
# 1728661993005994
# Stopping previous subprocess
# 267
# Error getting frame 271
# b''
# 1728661992919244
# Stopping previous subprocess
# 261
# FFMPEG get frame 261
# Error getting frame 267
# b''
# 1728661992875783
# Stopping previous subprocess
# 259
# FFMPEG get frame 259
# Error getting frame 261
# b''
# 1728661992875783
# Same frame being requested, wait for existing thread to finish
# 259
# 1728661992788646
# Stopping previous subprocess
# 253
# FFMPEG get frame 253
# Error getting frame 259
# b''
# 1728661992766878
# Stopping previous subprocess
# 252
# FFMPEG get frame 252
# Error getting frame 253
# b''
# FFMPEG get frame 250
# 1728661992723304
# Stopping previous subprocess
# 250
# Error getting frame 252
# b''
# FFMPEG get frame 248
# 1728661992701617
# Stopping previous subprocess
# 248
# Error getting frame 250
# b''
# 1728661992657927
# 246
# FFMPEG get frame 246
# 1728661992657927
# Frame already displayed
# 246
# 1728661992636769
# 244
# FFMPEG get frame 244
# 1728661992592840
# Stopping previous subprocess
# 242
# FFMPEG get frame 242
# Error getting frame 244
# b''
# 1728661992571076
# Stopping previous subprocess
# 240
# FFMPEG get frame 240
# Error getting frame 242
# b''
# 1728661992527991
# 238
# FFMPEG get frame 238
# 1728661992506378
# Stopping previous subprocess
# 236
# FFMPEG get frame 236
# Error getting frame 238
# b''
# 1728661992506378
# Same frame being requested, wait for existing thread to finish
# 236
# 1728661992462876
# 234
# FFMPEG get frame 234
# 1728661992441875
# Stopping previous subprocess
# 233
# FFMPEG get frame 233
# Error getting frame 234
# b''
# 1728661992376405
# Stopping previous subprocess
# 229
# FFMPEG get frame 229
# Error getting frame 233
# b''
# 1728661992376405
# Same frame being requested, wait for existing thread to finish
# 229
# 1728661992376405
# Same frame being requested, wait for existing thread to finish
# 229
# 1728661992355923
# Stopping previous subprocess
# 227
# FFMPEG get frame 227
# Error getting frame 229
# b''
# 1728661992289325
# Stopping previous subprocess
# 223
# FFMPEG get frame 223
# Error getting frame 227
# b''
# 1728661992289325
# Frame already displayed
# 223
# 1728661992245628
# 221
# FFMPEG get frame 221
# 1728661992158663
# Stopping previous subprocess
# 215
# FFMPEG get frame 215
# Error getting frame 221
# b''
# 1728661992158663
# Same frame being requested, wait for existing thread to finish
# 215
# 1728661992008252
# Stopping previous subprocess
# 206
# FFMPEG get frame 206
# Error getting frame 215
# b''
# FFMPEG get frame 204
# 1728661991965926
# Stopping previous subprocess
# 204
# Error getting frame 206
# b''
# 1728661991946470
# Stopping previous subprocess
# 203
# FFMPEG get frame 203
# Error getting frame 204
# b''
# 1728661991900782
# 200
# FFMPEG get frame 200
# 1728661991879014
# Stopping previous subprocess
# 199
# FFMPEG get frame 199
# Error getting frame 200
# b''
# 1728661991748214
# Stopping previous subprocess
# 191
# FFMPEG get frame 191
# Error getting frame 199
# b''
# FFMPEG get frame 187
# 1728661991681724
# Stopping previous subprocess
# 187
# Error getting frame 191
# b''
# 1728661991703477
# 188
# FFMPEG get frame 188
# 1728661991703477
# Same frame being requested, wait for existing thread to finish
# 188
# 1728661991748214
# Stopping previous subprocess
# 191
# FFMPEG get frame 191
# 1728661991769874
# Stopping previous subprocess
# 192
# FFMPEG get frame 192
# Error getting frame 191
# b''
# 1728661991813499
# Stopping previous subprocess
# 195
# FFMPEG get frame 195
# Error getting frame 192
# b''
# Error getting frame 188
# b''
# 1728661991835420
# Stopping previous subprocess
# 196
# FFMPEG get frame 196
# Error getting frame 195
# b''
# FFMPEG get frame 199
# 1728661991879014
# Stopping previous subprocess
# 199
# Error getting frame 196
# b''
# 1728661991879014
# Same frame being requested, wait for existing thread to finish
# 199
# 1728661991900782
# Stopping previous subprocess
# 200
# FFMPEG get frame 200
# Error getting frame 199
# b''
# 1728661991900782
# Same frame being requested, wait for existing thread to finish
# 200
# 1728661991946470
# Stopping previous subprocess
# 203
# FFMPEG get frame 203
# Error getting frame 200
# b''
# 1728661991965926
# Stopping previous subprocess
# 204
# FFMPEG get frame 204
# Error getting frame 203
# b''
# 1728661992008252
# Stopping previous subprocess
# 206
# FFMPEG get frame 206
# Error getting frame 204
# b''
# 1728661992008252
# Same frame being requested, wait for existing thread to finish
# 206
# 1728661992028886
# 208
# FFMPEG get frame 208
# 1728661992008252
# 206
# FFMPEG get frame 206
# 1728661992008252
# Frame already displayed
# 206
# 1728661992008252
# Frame already displayed
# 206
# 1728661992028886
# 208
# FFMPEG get frame 208
# 1728661992223989
# Stopping previous subprocess
# 219
# FFMPEG get frame 219
# 1728661992289325
# Stopping previous subprocess
# 223
# FFMPEG get frame 223
# Error getting frame 208
# b''
# Error getting frame 219
# b''
# 1728661992376405
# Stopping previous subprocess
# 229
# FFMPEG get frame 229
# Error getting frame 223
# b''
# 1728661992441875
# Stopping previous subprocess
# 233
# FFMPEG get frame 233
# Error getting frame 229
# b''
# 1728661992571076
# Stopping previous subprocess
# 240
# FFMPEG get frame 240
# Error getting frame 233
# b''
# Error getting frame 240
# b''
# FFMPEG get frame 244
# 1728661992636769
# Stopping previous subprocess
# 244
# 1728661992941019
# Stopping previous subprocess
# 263
# FFMPEG get frame 263
# Error getting frame 244
# b''
# 1728661993158228
# Stopping previous subprocess
# 276
# FFMPEG get frame 276
# Error getting frame 263
# b''
# FFMPEG get frame 278
# 1728661993201728
# Stopping previous subprocess
# 278
# Error getting frame 276
# b''
# 1728661993223597
# Stopping previous subprocess
# 280
# FFMPEG get frame 280
# Error getting frame 278
# b''
# 1728661993223597
# Frame already displayed
# 280
# 1728661993267139
# 282
# FFMPEG get frame 282
# 1728661993354150
# Stopping previous subprocess
# 288
# FFMPEG get frame 288
# Error getting frame 282
# b''
# 1728661993354150
# Same frame being requested, wait for existing thread to finish
# 288
# 1728661993397402
# Stopping previous subprocess
# 290
# FFMPEG get frame 290
# 1728661993419314
# Stopping previous subprocess
# 292
# FFMPEG get frame 292
# Error getting frame 288
# b''
# Error getting frame 290
# b''
# 1728661993419314
# Same frame being requested, wait for existing thread to finish
# 292
# 1728661993462981
# 294
# FFMPEG get frame 294
# 1728661993484718
# Stopping previous subprocess
# 295
# FFMPEG get frame 295
# Error getting frame 294
# b''
# 1728661993615204
# Stopping previous subprocess
# 303
# FFMPEG get frame 303
# Error getting frame 295
# b''
# 1728661993680801
# Stopping previous subprocess
# 307
# FFMPEG get frame 307
# Error getting frame 303
# b''
# 1728661993615204
# 303
# FFMPEG get frame 303
# 1728661993571616
# Stopping previous subprocess
# 301
# FFMPEG get frame 301
# Error getting frame 303
# b''
# 1728661993571616
# Same frame being requested, wait for existing thread to finish
# 301
# 1728661993549858
# Stopping previous subprocess
# FFMPEG get frame 299
# 299
# Error getting frame 301
# b''
# 1728661993571616
# 301
# FFMPEG get frame 301
# 1728661993571616
# Same frame being requested, wait for existing thread to finish
# 301
# 1728661993615204
# Stopping previous subprocess
# 303
# FFMPEG get frame 303
# Error getting frame 301
# b''
# 1728661993615204
# Same frame being requested, wait for existing thread to finish
# 303
# 1728661993680801
# 307
# FFMPEG get frame 307
# 1728661993680801
# Same frame being requested, wait for existing thread to finish
# 307
# 1728661993702328
# 309
# FFMPEG get frame 309
# 1728661993702328
# Same frame being requested, wait for existing thread to finish
# 309
# 1728661993746166
# 311
# FFMPEG get frame 311
# 1728661993746166
# Frame already displayed
# 311
# 1728661993811377
# 315
# FFMPEG get frame 315
# 1728661995326388
# Stopping previous subprocess
# 407
# FFMPEG get frame 407
# Error getting frame 315
# b''
# FFMPEG get frame 441
# 1728661995890141
# Stopping previous subprocess
# 441
# Error getting frame 407
# b''
# 1728661996645250
# Stopping previous subprocess
# 486
# FFMPEG get frame 486
# Error getting frame 441
# b''
# 1728661996667595
# Stopping previous subprocess
# 488
# FFMPEG get frame 488
# Error getting frame 486
# b''
# FFMPEG get frame 494
# 1728661996779608
# Stopping previous subprocess
# 494
# Error getting frame 488
# b''
# 1728661996779608
# Same frame being requested, wait for existing thread to finish
# 494
# 1728661996779608
# Same frame being requested, wait for existing thread to finish
# 494
# 1728661996779608
# Same frame being requested, wait for existing thread to finish
# 494
# 1728661996869734
# Stopping previous subprocess
# 500
# FFMPEG get frame 500
# 1728661996915233
# Stopping previous subprocess
# 503
# FFMPEG get frame 503
# Error getting frame 500
# b''
# Error getting frame 494
# b''
# 1728661997004404
# Stopping previous subprocess
# 508
# FFMPEG get frame 508
# Error getting frame 503
# b''
# 1728661997026334
# Stopping previous subprocess
# 509
# FFMPEG get frame 509
# Error getting frame 508
# b''
# FFMPEG get frame 512
# 1728661997069503
# Stopping previous subprocess
# 512
# Error getting frame 509
# b''
# 1728661997069503
# Same frame being requested, wait for existing thread to finish
# 512
# 1728661997069503
# Frame already displayed
# 512
# 1728661997134557
# 516
# FFMPEG get frame 516
# 1728661997221140
# Stopping previous subprocess
# 521
# FFMPEG get frame 521
# Error getting frame 516
# b''
# 1728661997200037
# 520
# FFMPEG get frame 520
# 1728661997200037
# Same frame being requested, wait for existing thread to finish
# 520
# 1728661997156199
# 517
# FFMPEG get frame 517
# 1728661997200037
# 520
# FFMPEG get frame 520
# 1728661997264581
# Stopping previous subprocess
# 524
# FFMPEG get frame 524
# Error getting frame 520
# b''
# 1728661997486519
# Stopping previous subprocess
# 537
# FFMPEG get frame 537
# Error getting frame 524
# b''
# 1728661997576097
# Stopping previous subprocess
# 542
# FFMPEG get frame 542
# Error getting frame 537
# b''
# 1728661997865468
# Stopping previous subprocess
# 560
# FFMPEG get frame 560
# 1728661998086186
# Stopping previous subprocess
# 573
# FFMPEG get frame 573
# Error getting frame 542
# b''
# Error getting frame 560
# b''
# 1728661998490305
# Stopping previous subprocess
# 598
# FFMPEG get frame 598
# Error getting frame 573
# b''
# FFMPEG get frame 615
# 1728661998773871
# Stopping previous subprocess
# 615
# Error getting frame 598
# b''
# 1728661998969953
# Stopping previous subprocess
# 627
# FFMPEG get frame 627
# Error getting frame 615
# b''
# 1728661998991022
# Stopping previous subprocess
# 628
# FFMPEG get frame 628
# Error getting frame 627
# b''
# 1728661999055353
# Stopping previous subprocess
# 632
# FFMPEG get frame 632
# Error getting frame 628
# b''
# 1728661999055353
# Same frame being requested, wait for existing thread to finish
# 632
# 1728661999098712
# Stopping previous subprocess
# 634
# FFMPEG get frame 634
# Error getting frame 632
# b''
# 1728661999120465
# 636
# FFMPEG get frame 636
# 1728661999185598
# Stopping previous subprocess
# 640
# FFMPEG get frame 640
# Error getting frame 636
# b''
# 1728661999207233
# Stopping previous subprocess
# 641
# FFMPEG get frame 641
# Error getting frame 640
# b''
# 1728661999273773
# Stopping previous subprocess
# 645
# FFMPEG get frame 645
# Error getting frame 641
# b''
# 1728661999273773
# Same frame being requested, wait for existing thread to finish
# 645
# 1728661999273773
# Same frame being requested, wait for existing thread to finish
# 645
# 1728661999316921
# Stopping previous subprocess
# 647
# FFMPEG get frame 647
# Error getting frame 645
# b''
# FFMPEG get frame 649
# 1728661999339621
# Stopping previous subprocess
# 649
# Error getting frame 647
# b''
# 1728661999339621
# Same frame being requested, wait for existing thread to finish
# 649
# 1728661999339621
# Same frame being requested, wait for existing thread to finish
# 649
# 1728661999339621
# Frame already displayed
# 649
# 1728661999316921
# 647
# FFMPEG get frame 647
# 1728661999316921
# Same frame being requested, wait for existing thread to finish
# 647
# 1728661999273773
# Stopping previous subprocess
# 645
# FFMPEG get frame 645
# Error getting frame 647
# b''
# 1728661999273773
# Same frame being requested, wait for existing thread to finish
# 645
# 1728661999207233
# Stopping previous subprocess
# 641
# FFMPEG get frame 641
# Error getting frame 645
# b''
# 1728661999207233
# Same frame being requested, wait for existing thread to finish
# 641
# 1728661999185598
# Stopping previous subprocess
# 640
# FFMPEG get frame 640
# Error getting frame 641
# b''
# 1728661999207233
# 641
# FFMPEG get frame 641
# 1728661999273773
# Stopping previous subprocess
# 645
# FFMPEG get frame 645
# Error getting frame 641
# b''
# 1728661999273773
# Same frame being requested, wait for existing thread to finish
# 645
# 1728661999316921
# 647
# FFMPEG get frame 647
# 1728661999406899
# Stopping previous subprocess
# 653
# FFMPEG get frame 653
# Error getting frame 647
# b''
# 1728661999564046
# Stopping previous subprocess
# 662
# FFMPEG get frame 662
# Error getting frame 653
# b''
# FFMPEG get frame 680
# 1728661999858004
# Stopping previous subprocess
# 680
# Error getting frame 662
# b''
# 1728662000262849
# Stopping previous subprocess
# 705
# FFMPEG get frame 705
# Error getting frame 680
# b''
# 1728662000400070
# Stopping previous subprocess
# 713
# FFMPEG get frame 713
# 1728662000622850
# Stopping previous subprocess
# 726
# FFMPEG get frame 726
# Error getting frame 705
# b''
# Error getting frame 713
# b''
# 1728662000692067
# Stopping previous subprocess
# 730
# FFMPEG get frame 730
# Error getting frame 726
# b''
# 1728662000823589
# Stopping previous subprocess
# 738
# FFMPEG get frame 738
# Error getting frame 730
# b''
# 1728662000978002
# Stopping previous subprocess
# 748
# FFMPEG get frame 748
# 1728662001045630
# Stopping previous subprocess
# 752
# FFMPEG get frame 752
# Error getting frame 748
# b''
# Error getting frame 738
# b''
# 1728662001113498
# Stopping previous subprocess
# 756
# FFMPEG get frame 756
# 1728662001338485
# Stopping previous subprocess
# 769
# FFMPEG get frame 769
# Error getting frame 756
# b''
# Error getting frame 752
# b''
# 1728662001472843
# Stopping previous subprocess
# 778
# FFMPEG get frame 778
# Error getting frame 769
# b''
# 1728662001494660
# Stopping previous subprocess
# 779
# FFMPEG get frame 779
# Error getting frame 778
# b''
# 1728662001494660
# Same frame being requested, wait for existing thread to finish
# 779
# 1728662001494660
# Frame already displayed
# 779
# 1728662001538015
# 781
# FFMPEG get frame 781
# 1728662001625015
# Stopping previous subprocess
# 787
# FFMPEG get frame 787
# Error getting frame 781
# b''
# FFMPEG get frame 788
# 1728662001646472
# Stopping previous subprocess
# 788
# Error getting frame 787
# b''
# 1728662001711716
# 792
# FFMPEG get frame 792
# 1728662001776299
# Stopping previous subprocess
# 796
# FFMPEG get frame 796
# Error getting frame 792
# b''
# 1728662002121739
# Stopping previous subprocess
# 817
# FFMPEG get frame 817
# Error getting frame 796
# b''
# FFMPEG get frame 825
# 1728662002252235
# Stopping previous subprocess
# 825
# Error getting frame 817
# b''
# FFMPEG get frame 827
# 1728662002295907
# Stopping previous subprocess
# 827
# Error getting frame 825
# b''
# 1728662002295907
# Frame already displayed
# 827
# 1728662002317939
# 829
# FFMPEG get frame 829
# 1728662002344000
# 830
# FFMPEG get frame 830
# 1728662002384203
# 833
# FFMPEG get frame 833
# 1728662002344000
# 830
# FFMPEG get frame 830
# 1728662002317939
# Stopping previous subprocess
# 829
# FFMPEG get frame 829
# Error getting frame 830
# b''
# 1728662002295907
# Stopping previous subprocess
# 827
# FFMPEG get frame 827
# Error getting frame 829
# b''
# 1728662002295907
# Same frame being requested, wait for existing thread to finish
# 827
# 1728662002252235
# Stopping previous subprocess
# 825
# FFMPEG get frame 825
# Error getting frame 827
# b''
# 1728662002230601
# Stopping previous subprocess
# 823
# FFMPEG get frame 823
# Error getting frame 825
# b''
# FFMPEG get frame 821
# 1728662002186959
# Stopping previous subprocess
# 821
# Error getting frame 823
# b''
# 1728662002230601
# 823
# FFMPEG get frame 823
# 1728662002252235
# 825
# FFMPEG get frame 825
# 1728662002449659
# Stopping previous subprocess
# 837
# FFMPEG get frame 837
# Error getting frame 825
# b''
# 1728662002834006
# Stopping previous subprocess
# 860
# FFMPEG get frame 860
# Error getting frame 837
# b''
# 1728662003014496
# Stopping previous subprocess
# 871
# FFMPEG get frame 871
# Error getting frame 860
# b''
# 1728662003400051
# Stopping previous subprocess
# 894
# FFMPEG get frame 894
# Error getting frame 871
# b''
# 1728662003759446
# Stopping previous subprocess
# 916
# FFMPEG get frame 916
# Error getting frame 894
# b''
# 1728662003827378
# Stopping previous subprocess
# 920
# FFMPEG get frame 920
# Error getting frame 916
# b''
# 1728662004201116
# Stopping previous subprocess
# 942
# FFMPEG get frame 942
# Error getting frame 920
# b''
# 1728662004440392
# Stopping previous subprocess
# 957
# FFMPEG get frame 957
# Error getting frame 942
# b''
# 1728662004679104
# Stopping previous subprocess
# 971
# FFMPEG get frame 971
# Error getting frame 957
# b''
# 1728662004872028
# Stopping previous subprocess
# 983
# FFMPEG get frame 983
# Error getting frame 971
# b''
# 1728662004936080
# Stopping previous subprocess
# 987
# FFMPEG get frame 987
# Error getting frame 983
# b''
# 1728662004936080
# Same frame being requested, wait for existing thread to finish
# 987
# 1728662004957411
# Stopping previous subprocess
# 988
# FFMPEG get frame 988
# Error getting frame 987
# b''
# 1728662004999989
# Stopping previous subprocess
# 990
# FFMPEG get frame 990
# Error getting frame 988
# b''
# 1728662004999989
# Same frame being requested, wait for existing thread to finish
# 990
# 1728662004999989
# Same frame being requested, wait for existing thread to finish
# 990
# 1728662004999989
# Same frame being requested, wait for existing thread to finish
# 990
# 1728662004999989
# Same frame being requested, wait for existing thread to finish
# 990
# 1728662004999989
# Same frame being requested, wait for existing thread to finish
# 990
# 1728662004957411
# Stopping previous subprocess
# 988
# FFMPEG get frame 988
# Error getting frame 990
# b''
# 1728662004957411
# Same frame being requested, wait for existing thread to finish
# 988
# 1728662004936080
# 987
# FFMPEG get frame 987
# 1728662004872028
# Stopping previous subprocess
# 983
# FFMPEG get frame 983
# Error getting frame 987
# b''
# 1728662004872028
# Same frame being requested, wait for existing thread to finish
# 983
# 1728662004850434
# 981
# FFMPEG get frame 981
# 1728662004807332
# Stopping previous subprocess
# 979
# FFMPEG get frame 979
# Error getting frame 981
# b''
# 1728662004785782
# Stopping previous subprocess
# 977
# FFMPEG get frame 977
# Error getting frame 979
# b''
# 1728662004743243
# Stopping previous subprocess
# 975
# FFMPEG get frame 975
# Error getting frame 977
# b''
# 1728662004721730
# 974
# FFMPEG get frame 974
# 1728662004721730
# Same frame being requested, wait for existing thread to finish
# 974
# 1728662004657468
# Stopping previous subprocess
# 970
# FFMPEG get frame 970
# 1728662004615196
# Stopping previous subprocess
# 967
# FFMPEG get frame 967
# Error getting frame 974
# b''
# Error getting frame 970
# b''
# 1728662004592309
# 966
# FFMPEG get frame 966
# 1728662004548998
# Stopping previous subprocess
# 963
# FFMPEG get frame 963
# Error getting frame 966
# b''
# 1728662004396797
# Stopping previous subprocess
# 954
# FFMPEG get frame 954
# Error getting frame 963
# b''
# FFMPEG get frame 950
# 1728662004331911
# Stopping previous subprocess
# 950
# Error getting frame 954
# b''
# 1728662004396797
# 954
# FFMPEG get frame 954
# 1728662004396797
# Same frame being requested, wait for existing thread to finish
# 954
# 1728662004440392
# Stopping previous subprocess
# 957
# FFMPEG get frame 957
# Error getting frame 954
# b''
# 1728662004440392
# Same frame being requested, wait for existing thread to finish
# 957
# 1728662004462137
# Stopping previous subprocess
# 958
# FFMPEG get frame 958
# Error getting frame 957
# b''
# 1728662004505572
# 961
# FFMPEG get frame 961
# 1728662004505572
# Frame already displayed
# 961
# 1728662004331911
# 950
# FFMPEG get frame 950
# 1728662003467845
# Stopping previous subprocess
# 898
# FFMPEG get frame 898
# Error getting frame 950
# b''
# FFMPEG get frame 598
# 1728661998490305
# Stopping previous subprocess
# 598
# Error getting frame 898
# b''
# FFMPEG get frame 441
# 1728661995890141
# Stopping previous subprocess
# 441
# Error getting frame 598
# b''
# 1728661991311538
# Stopping previous subprocess
# 164
# FFMPEG get frame 164
# Error getting frame 441
# b''
# 1728661990551730
# Stopping previous subprocess
# 118
# FFMPEG get frame 118
# Error getting frame 164
# b''
# 1728661990075432
# Stopping previous subprocess
# 90
# FFMPEG get frame 90
# Error getting frame 118
# b''
# 1728661989968982
# Stopping previous subprocess
# 83
# FFMPEG get frame 83
# Error getting frame 90
# b''
# FFMPEG get frame 60
# 1728661989582503
# Stopping previous subprocess
# 60
# Error getting frame 83
# b''
# 1728661989120916
# Stopping previous subprocess
# 32
# FFMPEG get frame 32
# 1728661988776323
# Stopping previous subprocess
# 11
# FFMPEG get frame 11
# Error getting frame 32
# b''
# Error getting frame 60
# b''
# 1728661988841327
# Stopping previous subprocess
# 15
# FFMPEG get frame 15
# Error getting frame 11
# b''
# 1728661988884548
# Stopping previous subprocess
# 18
# FFMPEG get frame 18
# Error getting frame 15
# b''
# 1728661988950013
# Stopping previous subprocess
# 22
# FFMPEG get frame 22
# Error getting frame 18
# b''
# 1728661988950013
# Frame already displayed
# 22
# 1728661988950013
# Frame already displayed
# 22
# 1728661988841327
# 15
# FFMPEG get frame 15
# 1728661988776323
# Stopping previous subprocess
# 11
# FFMPEG get frame 11
# Error getting frame 15
# b''
# 1728661988776323
# Same frame being requested, wait for existing thread to finish
# 11
# 1728661988711413
# Stopping previous subprocess
# 7
# FFMPEG get frame 7
# Error getting frame 11
# b''
# 1728661988646408
# 3
# FFMPEG get frame 3
# 1728661990723668
# 129
# FFMPEG get frame 129
# 1728661993941876
# Stopping previous subprocess
# 323
# FFMPEG get frame 323
# 1728661998311535
# Stopping previous subprocess
# 587
# FFMPEG get frame 587
# Error getting frame 323
# b''
# Error getting frame 129
# b''
# FFMPEG get frame 1124
# 1728662007211403
# Stopping previous subprocess
# 1124
# Error getting frame 587
# b''
# 1728662009481635
# Stopping previous subprocess
# 1261
# FFMPEG get frame 1261
# Error getting frame 1124
# b''
# 1728662012741891
# Stopping previous subprocess
# 1458
# FFMPEG get frame 1458
# Error getting frame 1261
# b''
# 1728662014776513
# Stopping previous subprocess
# 1580
# FFMPEG get frame 1580
# Error getting frame 1458
# b''
# FFMPEG get frame 1593
# 1728662014979795
# Stopping previous subprocess
# 1593
# Error getting frame 1580
# b''
# 1728662015093068
# Stopping previous subprocess
# 1600
# FFMPEG get frame 1600
# Error getting frame 1593
# b''
# FFMPEG get frame 1608
# 1728662015229139
# Stopping previous subprocess
# 1608
# Error getting frame 1600
# b''
# FFMPEG get frame 1634
# 1728662015672290
# Stopping previous subprocess
# 1634
# Error getting frame 1608
# b''
# 1728662016122727
# Stopping previous subprocess
# 1662
# FFMPEG get frame 1662
# Error getting frame 1634
# b''
# 1728662016122727
# Same frame being requested, wait for existing thread to finish
# 1662
# 1728662016056086
# Stopping previous subprocess
# 1658
# FFMPEG get frame 1658
# Error getting frame 1662
# b''
# FFMPEG get frame 1632
# 1728662015628035
# Stopping previous subprocess
# 1632
# Error getting frame 1658
# b''
# 1728662014640036
# Stopping previous subprocess
# 1572
# FFMPEG get frame 1572
# Error getting frame 1632
# b''
# 1728662014121709
# Stopping previous subprocess
# 1541
# FFMPEG get frame 1541
# Error getting frame 1572
# b''
# 1728662014075829
# Stopping previous subprocess
# FFMPEG get frame 1538
# 1538
# Error getting frame 1541
# b''
# 1728662014053007
# Stopping previous subprocess
# 1537
# FFMPEG get frame 1537
# Error getting frame 1538
# b''
# 1728662014053007
# Same frame being requested, wait for existing thread to finish
# 1537
# 1728662013939730
# Stopping previous subprocess
# 1530
# FFMPEG get frame 1530
# 1728662013558675
# Stopping previous subprocess
# 1507
# FFMPEG get frame 1507
# Error getting frame 1530
# b''
# Error getting frame 1537
# b''
# FFMPEG get frame 1477
# 1728662013056754
# Stopping previous subprocess
# 1477
# Error getting frame 1507
# b''
# 1728662011913247
# Stopping previous subprocess
# 1408
# FFMPEG get frame 1408
# Error getting frame 1477
# b''
# FFMPEG get frame 1387
# 1728662011564614
# Stopping previous subprocess
# 1387
# Error getting frame 1408
# b''
# 1728662011234844
# Stopping previous subprocess
# 1367
# FFMPEG get frame 1367
# Error getting frame 1387
# b''
# 1728662011257564
# Stopping previous subprocess
# 1368
# FFMPEG get frame 1368
# Error getting frame 1367
# b''
# FFMPEG get frame 1372
# 1728662011325506
# Stopping previous subprocess
# 1372
# Error getting frame 1368
# b''
# 1728662011434625
# Stopping previous subprocess
# 1379
# FFMPEG get frame 1379
# Error getting frame 1372
# b''
# FFMPEG get frame 1387
# 1728662011564614
# Stopping previous subprocess
# 1387
# Error getting frame 1379
# b''
# FFMPEG get frame 1393
# 1728662011673185
# Stopping previous subprocess
# 1393
# Error getting frame 1387
# b''
# 1728662011803301
# Stopping previous subprocess
# 1401
# FFMPEG get frame 1401
# Error getting frame 1393
# b''
# 1728662011824995
# Stopping previous subprocess
# 1402
# FFMPEG get frame 1402
# Error getting frame 1401
# b''
# 1728662011847256
# Stopping previous subprocess
# 1404
# FFMPEG get frame 1404
# Error getting frame 1402
# b''
# FFMPEG get frame 1405
# 1728662011869145
# Stopping previous subprocess
# 1405
# Error getting frame 1404
# b''
# FFMPEG get frame 1406
# 1728662011891255
# Stopping previous subprocess
# 1406
# Error getting frame 1405
# b''
# FFMPEG get frame 1410
# 1728662011956110
# Stopping previous subprocess
# 1410
# Error getting frame 1406
# b''
# 1728662012335647
# Stopping previous subprocess
# FFMPEG get frame 1433
# 1433
# Error getting frame 1410
# b''
# 1728662013516129
# Stopping previous subprocess
# 1504
# FFMPEG get frame 1504
# 1728662014526263
# Stopping previous subprocess
# 1565
# FFMPEG get frame 1565
# Error getting frame 1433
# b''
# Error getting frame 1504
# b''
# 1728662015477488
# Stopping previous subprocess
# 1623
# FFMPEG get frame 1623
# Error getting frame 1565
# b''
# FFMPEG get frame 1662
# 1728662016122727
# Stopping previous subprocess
# 1662
# Error getting frame 1623
# b''
# 1728662016144912
# Stopping previous subprocess
# 1663
# FFMPEG get frame 1663
# Error getting frame 1662
# b''
# 1728662016122727
# Stopping previous subprocess
# 1662
# FFMPEG get frame 1662
# Error getting frame 1663
# b''
# 1728662016100466
# Stopping previous subprocess
# 1660
# FFMPEG get frame 1660
# Error getting frame 1662
# b''
# 1728662016078219
# Stopping previous subprocess
# 1659
# FFMPEG get frame 1659
# 1728662016078219
# Same frame being requested, wait for existing thread to finish
# 1659
# Error getting frame 1660
# b''
# 1728662015967146
# Stopping previous subprocess
# 1652
# FFMPEG get frame 1652
# Error getting frame 1659
# b''
# 1728662015876935
# Stopping previous subprocess
# 1647
# FFMPEG get frame 1647
# Error getting frame 1652
# b''
# FFMPEG get frame 1641
# 1728662015786082
# Stopping previous subprocess
# 1641
# Error getting frame 1647
# b''
# 1728662015542323
# Stopping previous subprocess
# 1627
# FFMPEG get frame 1627
# Error getting frame 1641
# b''
# 1728662015365066
# Stopping previous subprocess
# 1616
# FFMPEG get frame 1616
# Error getting frame 1627
# b''
# 1728662015251919
# Stopping previous subprocess
# 1609
# FFMPEG get frame 1609
# Error getting frame 1616
# b''
# 1728662015138280
# Stopping previous subprocess
# 1602
# FFMPEG get frame 1602
# Error getting frame 1609
# b''
# 1728662014979795
# Stopping previous subprocess
# 1593
# FFMPEG get frame 1593
# Error getting frame 1602
# b''
# FFMPEG get frame 1591
# 1728662014957944
# Stopping previous subprocess
# 1591
# Error getting frame 1593
# b''
# FFMPEG get frame 1589
# 1728662014914120
# Stopping previous subprocess
# 1589
# Error getting frame 1591
# b''
# 1728662014957944
# Stopping previous subprocess
# 1591
# FFMPEG get frame 1591
# Error getting frame 1589
# b''
# 1728662014979795
# Stopping previous subprocess
# 1593
# FFMPEG get frame 1593
# Error getting frame 1591
# b''
# 1728662014640036
# Stopping previous subprocess
# 1572
# FFMPEG get frame 1572
# Error getting frame 1593
# b''
# FFMPEG get frame 1569
# 1728662014594719
# Stopping previous subprocess
# 1569
# Error getting frame 1572
# b''
# 1728662014640036
# Stopping previous subprocess
# 1572
# FFMPEG get frame 1572
# Error getting frame 1569
# b''
# 1728662014753912
# Stopping previous subprocess
# 1579
# FFMPEG get frame 1579
# Error getting frame 1572
# b''
# 1728662014824258
# Stopping previous subprocess
# 1583
# FFMPEG get frame 1583
# Error getting frame 1579
# b''
# FFMPEG get frame 1586
# 1728662014868724
# Stopping previous subprocess
# 1586
# Error getting frame 1583
# b''
# 1728662014824258
# Stopping previous subprocess
# 1583
# FFMPEG get frame 1583
# Error getting frame 1586
# b''
# FFMPEG get frame 1578
# 1728662014731171
# Stopping previous subprocess
# 1578
# Error getting frame 1583
# b''
# FFMPEG get frame 1576
# 1728662014708827
# Stopping previous subprocess
# 1576
# Error getting frame 1578
# b''
# 1728662014640036
# Stopping previous subprocess
# 1572
# FFMPEG get frame 1572
# Error getting frame 1576
# b''
# 1728662014640036
# Same frame being requested, wait for existing thread to finish
# 1572
# 1728662014549135
# Stopping previous subprocess
# 1567
# FFMPEG get frame 1567
# Error getting frame 1572
# b''
# 1728662014189318
# Stopping previous subprocess
# 1545
# FFMPEG get frame 1545
# Error getting frame 1567
# b''
# FFMPEG get frame 1506
# 1728662013535971
# Stopping previous subprocess
# 1506
# Error getting frame 1545
# b''
# 1728662012764591
# Stopping previous subprocess
# 1459
# FFMPEG get frame 1459
# Error getting frame 1506
# b''
# 1728662011891255
# Stopping previous subprocess
# 1406
# FFMPEG get frame 1406
# Error getting frame 1459
# b''
# FFMPEG get frame 1344
# 1728662010855629
# Stopping previous subprocess
# 1344
# Error getting frame 1406
# b''
# 1728662009503492
# Stopping previous subprocess
# 1262
# FFMPEG get frame 1262
# Error getting frame 1344
# b''
# 1728662008737848
# Stopping previous subprocess
# 1216
# FFMPEG get frame 1216
# Error getting frame 1262
# b''
# 1728662008354212
# Stopping previous subprocess
# 1193
# FFMPEG get frame 1193
# Error getting frame 1216
# b''
# FFMPEG get frame 1159
# 1728662007790249
# Stopping previous subprocess
# 1159
# Error getting frame 1193
# b''
# 1728662007767483
# Stopping previous subprocess
# 1157
# FFMPEG get frame 1157
# Error getting frame 1159
# b''
# 1728662007722201
# Stopping previous subprocess
# 1155
# FFMPEG get frame 1155
# Error getting frame 1157
# b''
# FFMPEG get frame 1157
# 1728662007767483
# Stopping previous subprocess
# 1157
# 1728662007790249
# Stopping previous subprocess
# 1159
# FFMPEG get frame 1159
# Error getting frame 1155
# b''
# Error getting frame 1157
# b''
# 1728662007790249
# Same frame being requested, wait for existing thread to finish
# 1159
# 1728662007744732
# Stopping previous subprocess
# 1156
# FFMPEG get frame 1156
# Error getting frame 1159
# b''
# 1728662007722201
# Stopping previous subprocess
# 1155
# FFMPEG get frame 1155
# Error getting frame 1156
# b''
# 1728662007722201
# Same frame being requested, wait for existing thread to finish
# 1155
# 1728662007722201
# Same frame being requested, wait for existing thread to finish
# 1155
# 1728662007722201
# Same frame being requested, wait for existing thread to finish
# 1155
# 1728662007699600
# Stopping previous subprocess
# 1153
# FFMPEG get frame 1153
# Error getting frame 1155
# b''
# FFMPEG get frame 1152
# 1728662007676782
# Stopping previous subprocess
# 1152
# Error getting frame 1153
# b''
# 1728662007632442
# Stopping previous subprocess
# 1149
# FFMPEG get frame 1149
# Error getting frame 1152
# b''
# 1728662007632442
# Same frame being requested, wait for existing thread to finish
# 1149
# 1728662007632442
# Same frame being requested, wait for existing thread to finish
# 1149
# 1728662007632442
# Same frame being requested, wait for existing thread to finish
# 1149
# 1728662007609838
# Stopping previous subprocess
# 1148
# FFMPEG get frame 1148
# Error getting frame 1149
# b''
# 1728662007587227
# 1147
# FFMPEG get frame 1147
# 1728662007564467
# 1145
# FFMPEG get frame 1145
# 1728662007541917
# Stopping previous subprocess
# 1144
# FFMPEG get frame 1144
# Error getting frame 1145
# b''
# 1728662007453389
# Stopping previous subprocess
# 1138
# FFMPEG get frame 1138
# Error getting frame 1144
# b''
# 1728662007453389
# Same frame being requested, wait for existing thread to finish
# 1138
# 1728662007453389
# Frame already displayed
# 1138
# 1728662007408007
# 1136
# FFMPEG get frame 1136
# 1728662007364592
# Stopping previous subprocess
# 1133
# FFMPEG get frame 1133
# Error getting frame 1136
# b''
# 1728662007364592
# Same frame being requested, wait for existing thread to finish
# 1133
# 1728662007364592
# Frame already displayed
# 1133
# 1728662007386034
# 1134
# FFMPEG get frame 1134
# 1728662007408007
# Stopping previous subprocess
# 1136
# FFMPEG get frame 1136
# Error getting frame 1134
# b''
# 1728662007408007
# Same frame being requested, wait for existing thread to finish
# 1136
# 1728662007453389
# Stopping previous subprocess
# 1138
# FFMPEG get frame 1138
# Error getting frame 1136
# b''
# 1728662007453389
# Same frame being requested, wait for existing thread to finish
# 1138
# 1728662007541917
# Stopping previous subprocess
# 1144
# FFMPEG get frame 1144
# Error getting frame 1138
# b''
# 1728662007541917
# Same frame being requested, wait for existing thread to finish
# 1144
# 1728662007632442
# Stopping previous subprocess
# 1149
# FFMPEG get frame 1149
# Error getting frame 1144
# b''
# 1728662007722201
# Stopping previous subprocess
# 1155
# FFMPEG get frame 1155
# Error getting frame 1149
# b''
# 1728662007767483
# Stopping previous subprocess
# 1157
# FFMPEG get frame 1157
# Error getting frame 1155
# b''
# 1728662007902805
# Stopping previous subprocess
# 1166
# FFMPEG get frame 1166
# Error getting frame 1157
# b''
# 1728662007948211
# Stopping previous subprocess
# 1168
# FFMPEG get frame 1168
# Error getting frame 1166
# b''
# 1728662008127688
# Stopping previous subprocess
# 1179
# FFMPEG get frame 1179
# Error getting frame 1168
# b''
# 1728662008218403
# Stopping previous subprocess
# 1185
# FFMPEG get frame 1185
# Error getting frame 1179
# b''
# 1728662008331393
# Stopping previous subprocess
# 1191
# FFMPEG get frame 1191
# Error getting frame 1185
# b''
# 1728662008445009
# Stopping previous subprocess
# 1198
# FFMPEG get frame 1198
# Error getting frame 1191
# b''
# 1728662008670175
# Stopping previous subprocess
# 1212
# FFMPEG get frame 1212
# Error getting frame 1198
# b''
# 1728662008737848
# Stopping previous subprocess
# 1216
# FFMPEG get frame 1216
# Error getting frame 1212
# b''
# 1728662009222929
# Stopping previous subprocess
# 1245
# FFMPEG get frame 1245
# Error getting frame 1216
# b''
# 1728662009373433
# Stopping previous subprocess
# 1254
# FFMPEG get frame 1254
# Error getting frame 1245
# b''
# 1728662009373433
# Same frame being requested, wait for existing thread to finish
# 1254
# 1728662009394934
# Stopping previous subprocess
# 1256
# FFMPEG get frame 1256
# Error getting frame 1254
# b''
# 1728662009394934
# Same frame being requested, wait for existing thread to finish
# 1256
# 1728662009438468
# Stopping previous subprocess
# 1258
# FFMPEG get frame 1258
# 1728662009459859
# Stopping previous subprocess
# 1260
# FFMPEG get frame 1260
# Error getting frame 1256
# b''
# Error getting frame 1258
# b''
# 1728662009547669
# Stopping previous subprocess
# 1265
# FFMPEG get frame 1265
# Error getting frame 1260
# b''
# 1728662009612056
# Stopping previous subprocess
# 1269
# FFMPEG get frame 1269
# Error getting frame 1265
# b''
# 1728662009612056
# Same frame being requested, wait for existing thread to finish
# 1269
# 1728662009654298
# Stopping previous subprocess
# 1271
# FFMPEG get frame 1271
# Error getting frame 1269
# b''
# 1728662009676182
# Stopping previous subprocess
# 1273
# FFMPEG get frame 1273
# Error getting frame 1271
# b''
# 1728662009698548
# Stopping previous subprocess
# 1274
# FFMPEG get frame 1274
# Error getting frame 1273
# b''
# 1728662009698548
# Same frame being requested, wait for existing thread to finish
# 1274
# 1728662009676182
# 1273
# FFMPEG get frame 1273
# 1728662009612056
# Stopping previous subprocess
# 1269
# FFMPEG get frame 1269
# Error getting frame 1273
# b''
# 1728662009590119
# Stopping previous subprocess
# 1267
# FFMPEG get frame 1267
# Error getting frame 1269
# b''
# 1728662009570988
# Stopping previous subprocess
# 1266
# FFMPEG get frame 1266
# Error getting frame 1267
# b''
# 1728662009525304
# Stopping previous subprocess
# 1264
# FFMPEG get frame 1264
# Error getting frame 1266
# b''
# 1728662009503492
# Stopping previous subprocess
# 1262
# FFMPEG get frame 1262
# Error getting frame 1264
# b''
# 1728662009459859
# Stopping previous subprocess
# 1260
# FFMPEG get frame 1260
# Error getting frame 1262
# b''
# 1728662009459859
# Same frame being requested, wait for existing thread to finish
# 1260
# 1728662009438468
# Stopping previous subprocess
# 1258
# FFMPEG get frame 1258
# Error getting frame 1260
# b''
# 1728662009459859
# 1260
# FFMPEG get frame 1260
# 1728662009459859
# Same frame being requested, wait for existing thread to finish
# 1260
# 1728662009503492
# Stopping previous subprocess
# 1262
# FFMPEG get frame 1262
# Error getting frame 1260
# b''
# 1728662009525304
# Stopping previous subprocess
# 1264
# FFMPEG get frame 1264
# Error getting frame 1262
# b''
# 1728662009525304
# Same frame being requested, wait for existing thread to finish
# 1264
# 1728662009525304
# Same frame being requested, wait for existing thread to finish
# 1264
# 1728662009547669
# 1265
# FFMPEG get frame 1265
# 1728662009590119
# Stopping previous subprocess
# 1267
# FFMPEG get frame 1267
# Error getting frame 1265
# b''
# 1728662009698548
# Stopping previous subprocess
# 1274
# FFMPEG get frame 1274
# 1728662009766482
# Stopping previous subprocess
# 1278
# FFMPEG get frame 1278
# Error getting frame 1267
# b''
# Error getting frame 1274
# b''
# 1728662009834871
# Stopping previous subprocess
# 1282
# FFMPEG get frame 1282
# Error getting frame 1278
# b''
# FFMPEG get frame 1285
# 1728662009879462
# Stopping previous subprocess
# 1285
# Error getting frame 1282
# b''
# 1728662010059925
# Stopping previous subprocess
# 1296
# FFMPEG get frame 1296
# 1728662010190788
# Stopping previous subprocess
# 1304
# FFMPEG get frame 1304
# Error getting frame 1285
# b''
# Error getting frame 1296
# b''
# 1728662010298798
# Stopping previous subprocess
# 1310
# FFMPEG get frame 1310
# Error getting frame 1304
# b''
# FFMPEG get frame 1323
# 1728662010517378
# Stopping previous subprocess
# 1323
# Error getting frame 1310
# b''
# 1728662010583206
# Stopping previous subprocess
# FFMPEG get frame 1327
# 1327
# Error getting frame 1323
# b''
# 1728662010719278
# Stopping previous subprocess
# 1336
# FFMPEG get frame 1336
# Error getting frame 1327
# b''
# 1728662010742477
# Stopping previous subprocess
# 1337
# FFMPEG get frame 1337
# Error getting frame 1336
# b''
# 1728662010742477
# Same frame being requested, wait for existing thread to finish
# 1337
# 1728662010765000
# Stopping previous subprocess
# 1338
# FFMPEG get frame 1338
# 1728662010765000
# Same frame being requested, wait for existing thread to finish
# 1338
# Error getting frame 1337
# b''
# 1728662010765000
# Same frame being requested, wait for existing thread to finish
# 1338
# 1728662010765000
# Same frame being requested, wait for existing thread to finish
# 1338
# 1728662010765000
# Same frame being requested, wait for existing thread to finish
# 1338
# 1728662010765000
# Same frame being requested, wait for existing thread to finish
# 1338
# 1728662010787396
# Stopping previous subprocess
# 1340
# FFMPEG get frame 1340
# 1728662010900912
# Stopping previous subprocess
# 1347
# FFMPEG get frame 1347
# Error getting frame 1338
# b''
# Error getting frame 1340
# b''
# 1728662011190881
# Stopping previous subprocess
# 1364
# FFMPEG get frame 1364
# Error getting frame 1347
# b''
# FFMPEG get frame 1375
# 1728662011369427
# Stopping previous subprocess
# 1375
# Error getting frame 1364
# b''
# FFMPEG get frame 1383
# 1728662011500156
# Stopping previous subprocess
# 1383
# Error getting frame 1375
# b''
# 1728662011500156
# Same frame being requested, wait for existing thread to finish
# 1383
# 1728662011542970
# Stopping previous subprocess
# 1385
# FFMPEG get frame 1385
# Error getting frame 1383
# b''
# 1728662011586377
# Stopping previous subprocess
# 1388
# FFMPEG get frame 1388
# Error getting frame 1385
# b''
# 1728662011586377
# Same frame being requested, wait for existing thread to finish
# 1388
# 1728662011608067
# Stopping previous subprocess
# 1389
# FFMPEG get frame 1389
# Error getting frame 1388
# b''
# FFMPEG get frame 1392
# 1728662011651697
# Stopping previous subprocess
# 1392
# Error getting frame 1389
# b''
# FFMPEG get frame 1395
# 1728662011696385
# Stopping previous subprocess
# 1395
# Error getting frame 1392
# b''
# FFMPEG get frame 1396
# 1728662011716467
# Stopping previous subprocess
# 1396
# Error getting frame 1395
# b''
# 1728662011716467
# Same frame being requested, wait for existing thread to finish
# 1396
# 1728662011738250
# Stopping previous subprocess
# 1397
# Error getting frame 1396
# b''
# FFMPEG get frame 1397
# 1728662011759976
# Stopping previous subprocess
# 1398
# FFMPEG get frame 1398
# Error getting frame 1397
# b''
# 1728662011803301
# Stopping previous subprocess
# 1401
# FFMPEG get frame 1401
# 1728662011847256
# Stopping previous subprocess
# 1404
# Error getting frame 1398
# b''
# FFMPEG get frame 1404
# 1728662011847256
# Same frame being requested, wait for existing thread to finish
# 1404
# 1728662011824995
# Stopping previous subprocess
# 1402
# FFMPEG get frame 1402
# Error getting frame 1404
# b''
# FFMPEG get frame 1401
# 1728662011803301
# Stopping previous subprocess
# 1401
# Error getting frame 1402
# b''
# 1728662011803301
# Same frame being requested, wait for existing thread to finish
# 1401
# 1728662011759976
# Stopping previous subprocess
# 1398
# FFMPEG get frame 1398
# Error getting frame 1401
# b''
# 1728662011759976
# Same frame being requested, wait for existing thread to finish
# 1398
# Error getting frame 1401
# b''
# 1728662011759976
# Frame already displayed
# 1398
# 1728662011803301
# 1401
# FFMPEG get frame 1401
# 1728662011803301
# Same frame being requested, wait for existing thread to finish
# 1401
# 1728662011824995
# Stopping previous subprocess
# 1402
# FFMPEG get frame 1402
# Error getting frame 1401
# b''
# FFMPEG get frame 1404
# 1728662011847256
# ...
# Error getting frame 3312
# b''
# FFMPEG get frame 3249
# 1728662042418659
# Stopping previous subprocess
# 3249
# Error getting frame 3261
# b''
# FFMPEG get frame 3236
# 1728662042215124
# Stopping previous subprocess
# 3236
# Error getting frame 3249
# b''
# 1728662041971370
# Stopping previous subprocess
# 3222
# FFMPEG get frame 3222
# 1728662041798176
# Stopping previous subprocess
# 3211
# FFMPEG get frame 3211
# Error getting frame 3222
# b''
# Error getting frame 3236
# b''
# 1728662041624469
# Stopping previous subprocess
# 3201
# FFMPEG get frame 3201
# Error getting frame 3211
# b''
# 1728662041448158
# Stopping previous subprocess
# 3190
# FFMPEG get frame 3190
# Error getting frame 3201
# b''
# FFMPEG get frame 3183
# 1728662041334808
# Stopping previous subprocess
# 3183
# Error getting frame 3190
# b''
# 1728662041114232
# Stopping previous subprocess
# 3170
# FFMPEG get frame 3170
# Error getting frame 3183
# b''
# FFMPEG get frame 3163
# 1728662041002676
# Stopping previous subprocess
# 3163
# Error getting frame 3170
# b''
# 1728662040800382
# Stopping previous subprocess
# 3151
# FFMPEG get frame 3151
# Error getting frame 3163
# b''
# 1728662040755804
# Stopping previous subprocess
# 3148
# FFMPEG get frame 3148
# Error getting frame 3151
# b''
# 1728662040733719
# Stopping previous subprocess
# 3147
# FFMPEG get frame 3147
# Error getting frame 3148
# b''
# 1728662040755804
# Stopping previous subprocess
# 3148
# FFMPEG get frame 3148
# Error getting frame 3147
# b''
# FFMPEG get frame 3156
# 1728662040890334
# Stopping previous subprocess
# 3156
# Error getting frame 3148
# b''
# 1728662040890334
# Same frame being requested, wait for existing thread to finish
# 3156
# 1728662040848141
# 3154
# FFMPEG get frame 3154
# 1728662040822908
# Stopping previous subprocess
# 3152
# FFMPEG get frame 3152
# Error getting frame 3154
# b''
# 1728662040822908
# Same frame being requested, wait for existing thread to finish
# 3152
# 1728662040800382
# Stopping previous subprocess
# 3151
# FFMPEG get frame 3151
# Error getting frame 3152
# b''
# 1728662040822908
# Stopping previous subprocess
# 3152
# FFMPEG get frame 3152
# Error getting frame 3151
# b''
# FFMPEG get frame 3154
# 1728662040848141
# Stopping previous subprocess
# 3154
# Error getting frame 3152
# b''
# 1728662040912782
# Stopping previous subprocess
# 3158
# FFMPEG get frame 3158
# 1728662040912782
# Same frame being requested, wait for existing thread to finish
# 3158
# Error getting frame 3154
# b''
# 1728662040980297
# Stopping previous subprocess
# 3162
# FFMPEG get frame 3162
# Error getting frame 3158
# b''
# 1728662041070304
# Stopping previous subprocess
# 3167
# FFMPEG get frame 3167
# Error getting frame 3162
# b''
# 1728662041070304
# Same frame being requested, wait for existing thread to finish
# 3167
# 1728662041092216
# Stopping previous subprocess
# 3169
# FFMPEG get frame 3169
# Error getting frame 3167
# b''
# 1728662041114232
# Stopping previous subprocess
# 3170
# FFMPEG get frame 3170
# Error getting frame 3169
# b''
# 1728662041114232
# Same frame being requested, wait for existing thread to finish
# 3170
# 1728662041179836
# Stopping previous subprocess
# 3174
# FFMPEG get frame 3174
# Error getting frame 3170
# b''
# 1728662041245957
# Stopping previous subprocess
# 3178
# FFMPEG get frame 3178
# Error getting frame 3174
# b''
# 1728662041245957
# Same frame being requested, wait for existing thread to finish
# 3178
# 1728662041334808
# Stopping previous subprocess
# 3183
# FFMPEG get frame 3183
# Error getting frame 3178
# b''
# 1728662041425470
# Stopping previous subprocess
# 3189
# FFMPEG get frame 3189
# 1728662041448158
# Stopping previous subprocess
# 3190
# FFMPEG get frame 3190
# Error getting frame 3189
# b''
# 1728662041448158
# Same frame being requested, wait for existing thread to finish
# 3190
# 1728662041448158
# Same frame being requested, wait for existing thread to finish
# 3190
# 1728662041492042
# Stopping previous subprocess
# 3193
# FFMPEG get frame 3193
# Error getting frame 3190
# b''
# Error getting frame 3183
# b''
# 1728662041448158
# 3190
# FFMPEG get frame 3190
# 1728662041448158
# Same frame being requested, wait for existing thread to finish
# 3190
# 1728662041448158
# Same frame being requested, wait for existing thread to finish
# 3190
# 1728662041425470
# Stopping previous subprocess
# 3189
# FFMPEG get frame 3189
# Error getting frame 3190
# b''
# FFMPEG get frame 3187
# 1728662041404158
# Stopping previous subprocess
# 3187
# Error getting frame 3189
# b''
# 1728662041360125
# Stopping previous subprocess
# 3185
# FFMPEG get frame 3185
# 1728662041334808
# Stopping previous subprocess
# 3183
# FFMPEG get frame 3183
# Error getting frame 3187
# b''
# Error getting frame 3185
# b''
# 1728662041334808
# Same frame being requested, wait for existing thread to finish
# 3183
# 1728662041289875
# 3181
# FFMPEG get frame 3181
# 1728662041245957
# Stopping previous subprocess
# 3178
# FFMPEG get frame 3178
# Error getting frame 3181
# b''
# 1728662041245957
# Same frame being requested, wait for existing thread to finish
# 3178
# 1728662041201941
# Stopping previous subprocess
# 3175
# FFMPEG get frame 3175
# Error getting frame 3178
# b''
# 1728662041179836
# Stopping previous subprocess
# 3174
# FFMPEG get frame 3174
# Error getting frame 3175
# b''
# 1728662041114232
# Stopping previous subprocess
# 3170
# FFMPEG get frame 3170
# Error getting frame 3174
# b''
# 1728662041092216
# Stopping previous subprocess
# 3169
# FFMPEG get frame 3169
# Error getting frame 3170
# b''
# 1728662041070304
# 3167
# FFMPEG get frame 3167
# 1728662041002676
# Stopping previous subprocess
# 3163
# FFMPEG get frame 3163
# Error getting frame 3167
# b''
# 1728662040980297
# Stopping previous subprocess
# 3162
# FFMPEG get frame 3162
# Error getting frame 3163
# b''
# 1728662040935226
# Stopping previous subprocess
# 3159
# FFMPEG get frame 3159
# Error getting frame 3162
# b''
# 1728662040890334
# Stopping previous subprocess
# 3156
# FFMPEG get frame 3156
# Error getting frame 3159
# b''
# 1728662040848141
# Stopping previous subprocess
# 3154
# FFMPEG get frame 3154
# Error getting frame 3156
# b''
# 1728662040848141
# Same frame being requested, wait for existing thread to finish
# 3154
# 1728662040822908
# Stopping previous subprocess
# 3152
# FFMPEG get frame 3152
# Error getting frame 3154
# b''
# 1728662040848141
# 3154
# FFMPEG get frame 3154
# 1728662040848141
# Same frame being requested, wait for existing thread to finish
# 3154
# 1728662040912782
# Stopping previous subprocess
# 3158
# FFMPEG get frame 3158
# 1728662040935226
# Stopping previous subprocess
# 3159
# FFMPEG get frame 3159
# Error getting frame 3154
# b''
# Error getting frame 3158
# b''
# 1728662040980297
# Stopping previous subprocess
# 3162
# FFMPEG get frame 3162
# Error getting frame 3159
# b''
# 1728662040935226
# 3159
# FFMPEG get frame 3159
# 1728662040912782
# Stopping previous subprocess
# 3158
# FFMPEG get frame 3158
# Error getting frame 3159
# b''
# 1728662040890334
# Stopping previous subprocess
# 3156
# FFMPEG get frame 3156
# Error getting frame 3158
# b''
# FFMPEG get frame 3154
# 1728662040848141
# Stopping previous subprocess
# 3154
# Error getting frame 3156
# b''
# 1728662040890334
# 3156
# FFMPEG get frame 3156
# 1728662040912782
# Stopping previous subprocess
# 3158
# FFMPEG get frame 3158
# Error getting frame 3156
# b''
# 1728662041002676
# Stopping previous subprocess
# 3163
# FFMPEG get frame 3163
# 1728662041179836
# Stopping previous subprocess
# 3174
# FFMPEG get frame 3174
# Error getting frame 3163
# b''
# Error getting frame 3158
# b''
# 1728662041448158
# Stopping previous subprocess
# 3190
# FFMPEG get frame 3190
# Error getting frame 3174
# b''
# 1728662041602345
# Stopping previous subprocess
# 3199
# FFMPEG get frame 3199
# Error getting frame 3190
# b''
# 1728662041690707
# Stopping previous subprocess
# 3205
# FFMPEG get frame 3205
# Error getting frame 3199
# b''
# 1728662041712207
# Stopping previous subprocess
# FFMPEG get frame 3206
# 3206
# Error getting frame 3205
# b''
# 1728662041712207
# Same frame being requested, wait for existing thread to finish
# 3206
# 1728662041755380
# Stopping previous subprocess
# 3209
# FFMPEG get frame 3209
# Error getting frame 3206
# b''
# 1728662041863341
# Stopping previous subprocess
# 3215
# FFMPEG get frame 3215
# Error getting frame 3209
# b''
# 1728662041949596
# Stopping previous subprocess
# 3220
# FFMPEG get frame 3220
# Error getting frame 3215
# b''
# 1728662041971370
# Stopping previous subprocess
# 3222
# FFMPEG get frame 3222
# Error getting frame 3220
# b''
# 1728662042104068
# Stopping previous subprocess
# 3230
# FFMPEG get frame 3230
# Error getting frame 3222
# b''
# 1728662042147977
# Stopping previous subprocess
# 3232
# FFMPEG get frame 3232
# 1728662042192476
# Stopping previous subprocess
# 3235
# FFMPEG get frame 3235
# Error getting frame 3230
# b''
# Error getting frame 3232
# b''
# 1728662042215124
# Stopping previous subprocess
# 3236
# FFMPEG get frame 3236
# Error getting frame 3235
# b''
# 1728662042396585
# Stopping previous subprocess
# 3247
# FFMPEG get frame 3247
# Error getting frame 3236
# b''
# 1728662042549260
# Stopping previous subprocess
# 3257
# FFMPEG get frame 3257
# Error getting frame 3247
# b''
# 1728662042729191
# Stopping previous subprocess
# 3267
# FFMPEG get frame 3267
# Error getting frame 3257
# b''
# 1728662042797540
# Stopping previous subprocess
# 3272
# FFMPEG get frame 3272
# Error getting frame 3267
# b''
# 1728662042729191
# Stopping previous subprocess
# 3267
# FFMPEG get frame 3267
# Error getting frame 3272
# b''
# 1728662042729191
# Same frame being requested, wait for existing thread to finish
# 3267
# 1728662042706431
# Stopping previous subprocess
# 3266
# FFMPEG get frame 3266
# Error getting frame 3267
# b''
# FFMPEG get frame 3263
# 1728662042661013
# Stopping previous subprocess
# 3263
# Error getting frame 3266
# b''
# 1728662042661013
# Same frame being requested, wait for existing thread to finish
# 3263
# 1728662042615523
# Stopping previous subprocess
# 3261
# FFMPEG get frame 3261
# Error getting frame 3263
# b''
# 1728662042661013
# 3263
# FFMPEG get frame 3263
# 1728662042661013
# Same frame being requested, wait for existing thread to finish
# 3263
# 1728662042706431
# Stopping previous subprocess
# 3266
# FFMPEG get frame 3266
# Error getting frame 3263
# b''
# FFMPEG get frame 3267
# 1728662042729191
# Stopping previous subprocess
# 3267
# Error getting frame 3266
# b''
# 1728662042797540
# Stopping previous subprocess
# 3272
# FFMPEG get frame 3272
# Error getting frame 3267
# b''
# 1728662042820164
# Stopping previous subprocess
# 3273
# FFMPEG get frame 3273
# Error getting frame 3272
# b''
# 1728662042820164
# Same frame being requested, wait for existing thread to finish
# 3273
# 1728662042820164
# Same frame being requested, wait for existing thread to finish
# 3273
# 1728662042842690
# Stopping previous subprocess
# 3274
# FFMPEG get frame 3274
# Error getting frame 3273
# b''
# 1728662042887999
# Stopping previous subprocess
# 3277
# FFMPEG get frame 3277
# Error getting frame 3274
# b''
# 1728662042887999
# Same frame being requested, wait for existing thread to finish
# 3277
# 1728662042910680
# 3278
# FFMPEG get frame 3278
# 1728662042933184
# Stopping previous subprocess
# 3280
# FFMPEG get frame 3280
# Error getting frame 3278
# b''
# 1728662042978249
# Stopping previous subprocess
# 3282
# FFMPEG get frame 3282
# Error getting frame 3280
# b''
# 1728662042933184
# 3280
# FFMPEG get frame 3280
# 1728662042933184
# Same frame being requested, wait for existing thread to finish
# 3280
# 1728662042887999
# Stopping previous subprocess
# 3277
# FFMPEG get frame 3277
# 1728662042549260
# Stopping previous subprocess
# 3257
# FFMPEG get frame 3257
# Error getting frame 3277
# b''
# Error getting frame 3280
# b''
# 1728662042282839
# Stopping previous subprocess
# 3240
# FFMPEG get frame 3240
# Error getting frame 3257
# b''
# 1728662040375414
# Stopping previous subprocess
# 3125
# FFMPEG get frame 3125
# Error getting frame 3240
# b''
# 1728662038569136
# Stopping previous subprocess
# 3016
# FFMPEG get frame 3016
# Error getting frame 3125
# b''
# FFMPEG get frame 2827
# 1728662035437918
# Stopping previous subprocess
# 2827
# Error getting frame 3016
# b''
# 1728662033684288
# Stopping previous subprocess
# 2722
# FFMPEG get frame 2722
# 1728662031745248
# Stopping previous subprocess
# 2605
# FFMPEG get frame 2605
# Error getting frame 2827
# b''
# Error getting frame 2722
# b''
# 1728662030965786
# Stopping previous subprocess
# 2557
# FFMPEG get frame 2557
# Error getting frame 2605
# b''
# FFMPEG get frame 2446
# 1728662029116950
# Stopping previous subprocess
# 2446
# Error getting frame 2557
# b''
# 1728662028943856
# Stopping previous subprocess
# 2435
# FFMPEG get frame 2435
# Error getting frame 2446
# b''
# 1728662031723147
# 2603
# FFMPEG get frame 2603
# 1728662031991574
# Stopping previous subprocess
# 2619
# FFMPEG get frame 2619
# 1728662032134282
# Stopping previous subprocess
# 2628
# FFMPEG get frame 2628
# Error getting frame 2619
# b''
# Error getting frame 2603
# b''
# 1728662032242567
# Stopping previous subprocess
# 2635
# FFMPEG get frame 2635
# Error getting frame 2628
# b''
# 1728662032307963
# Stopping previous subprocess
# 2638
# FFMPEG get frame 2638
# Error getting frame 2635
# b''
# 1728662032351534
# Stopping previous subprocess
# 2641
# FFMPEG get frame 2641
# Error getting frame 2638
# b''
# 1728662033578385
# Stopping previous subprocess
# 2715
# FFMPEG get frame 2715
# Error getting frame 2641
# b''
# 1728662033945796
# Stopping previous subprocess
# 2737
# FFMPEG get frame 2737
# Error getting frame 2715
# b''
# 1728662034484228
# Stopping previous subprocess
# 2770
# FFMPEG get frame 2770
# Error getting frame 2737
# b''
# FFMPEG get frame 2781
# 1728662034665330
# Stopping previous subprocess
# 2781
# Error getting frame 2770
# b''
# FFMPEG get frame 2783
# 1728662034710770
# Stopping previous subprocess
# 2783
# Error getting frame 2781
# b''
# 1728662034910868
# Stopping previous subprocess
# 2796
# FFMPEG get frame 2796
# Error getting frame 2783
# b''
# 1728662034997390
# Stopping previous subprocess
# 2801
# FFMPEG get frame 2801
# Error getting frame 2796
# b''
# 1728662035108295
# Stopping previous subprocess
# 2807
# FFMPEG get frame 2807
# Error getting frame 2801
# b''
# FFMPEG get frame 2815
# 1728662035239097
# Stopping previous subprocess
# 2815
# Error getting frame 2807
# b''
# 1728662035239097
# Same frame being requested, wait for existing thread to finish
# 2815
# 1728662035239097
# Same frame being requested, wait for existing thread to finish
# 2815
# 1728662035172642
# Stopping previous subprocess
# 2811
# FFMPEG get frame 2811
# 1728662035108295
# Stopping previous subprocess
# 2807
# FFMPEG get frame 2807
# Error getting frame 2811
# b''
# Error getting frame 2815
# b''
# 1728662035019135
# Stopping previous subprocess
# 2802
# FFMPEG get frame 2802
# Error getting frame 2807
# b''
# 1728662035019135
# Same frame being requested, wait for existing thread to finish
# 2802
# 1728662034997390
# Stopping previous subprocess
# 2801
# FFMPEG get frame 2801
# Error getting frame 2802
# b''
# 1728662034975962
# Stopping previous subprocess
# 2799
# FFMPEG get frame 2799
# Error getting frame 2801
# b''
# 1728662034910868
# Stopping previous subprocess
# 2796
# FFMPEG get frame 2796
# Error getting frame 2799
# b''
# 1728662034755999
# Stopping previous subprocess
# 2786
# FFMPEG get frame 2786
# Error getting frame 2796
# b''
# 1728662034484228
# Stopping previous subprocess
# 2770
# FFMPEG get frame 2770
# Error getting frame 2786
# b''
# 1728662034215676
# Stopping previous subprocess
# 2754
# FFMPEG get frame 2754
# Error getting frame 2770
# b''
# 1728662033535501
# Stopping previous subprocess
# 2713
# FFMPEG get frame 2713
# 1728662033321494
# Stopping previous subprocess
# 2700
# FFMPEG get frame 2700
# Error getting frame 2713
# b''
# Error getting frame 2754
# b''
# 1728662032613094
# Stopping previous subprocess
# 2657
# FFMPEG get frame 2657
# 1728662031701273
# Stopping previous subprocess
# 2602
# FFMPEG get frame 2602
# Error getting frame 2700
# b''
# Error getting frame 2657
# b''
# 1728662030684045
# Stopping previous subprocess
# 2540
# FFMPEG get frame 2540
# Error getting frame 2602
# b''
# 1728662029520792
# Stopping previous subprocess
# 2470
# FFMPEG get frame 2470
# Error getting frame 2540
# b''
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 23, in SegmentListEntry.__init__.<locals>.<lambda>(_)
#      20 move_up_button = widgets.Button(description='⬆️', layout=widgets.Layout(width='auto'))
#      21 remove_button = widgets.Button(description='X', layout=widgets.Layout(width='auto'))
# ---> 23 remove_button.on_click(lambda _: self.segment_list_manager.removeSegment(self))
#      24 move_down_button.on_click(lambda _: self.segment_list_manager.move_down(self))
#      25 move_up_button.on_click(lambda _: self.segment_list_manager.move_up(self))
#
# Cell In[9], line 90, in SegmentListManager.removeSegment(self, item)
#      89 def removeSegment(self, item) -> None:
# ---> 90     idx = self.segment_list_items.index(item)
#      91     self.segments.pop(idx)
#      92     self.segment_notifier.notify()
#
# ValueError: <__main__.SegmentListEntry object at 0x7f307d428e60> is not in list
