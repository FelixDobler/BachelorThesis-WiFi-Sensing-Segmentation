# %%
from matplotlib import pyplot as plt, patches
import numpy as np
from ipywidgets import widgets, interact
from IPython.display import display
import csidata as cid
import pandas as pd
from os.path import basename, splitext, exists

# %%
frame_timestamps = None

filename = 'record/prod_data/csi/user1/2024-10-11T17-53-07-740347_seq-wd.raw'


label_save_file = 'record/prod_data/user1.csv'

# %%
data = cid.load(filename)
csi = data.csi

input_reduction = 20
sel = np.index_exp[::input_reduction, 2, 2, 0]

csiTrace = csi[sel]
csiTrace.shape
# Out:
# (2679,)

# %%
def set_csi_trace(rx_idx, tx_idx, subcarrier_idx):
    global csiTrace
    csiTrace = csi[::input_reduction, rx_idx, tx_idx, subcarrier_idx]
    # plot_csi_trace(csiTrace)

# %%
import subprocess
import threading

img_thread: threading.Thread = None
img_subprocess: subprocess.Popen = None
prev_frame_idx = -1
video_path = None
image = None
tmp_file = None

def display_video_frame(frame_idx):
    global img_thread, img_subprocess, prev_frame_idx, tmp_file
    # print(f'Requesting frame {frame_idx}')
    if img_thread is not None and img_thread.is_alive():
        if prev_frame_idx == frame_idx:
            print('Same frame being requested, wait for existing thread to finish')
            return
        
        print('Stopping previous subprocess')
        img_subprocess.kill()
    else:
        if prev_frame_idx == frame_idx:
            print('Frame already displayed')
            return
    
    # print('Creating new thread')
    img_thread = threading.Thread(target=get_video_frame, args=(frame_idx,))
    img_thread.start()
    prev_frame_idx = frame_idx


def get_video_frame(frame_idx):
    global image, img_subprocess, tmp_file

    print(f'FFMPEG get frame {frame_idx}')
    img_subprocess = subprocess.Popen(fr'ffmpeg -v error -f rawvideo -pix_fmt yuv422p -s 1280x720 -framerate 60 -i {tmp_file} -vf select=eq(n\,{frame_idx}) -vframes 1 -f image2 -c:v png pipe:'.split(), 
                                  stdout=subprocess.PIPE, stdin=subprocess.PIPE, stderr=subprocess.PIPE)
    # print('FFMPEG process started')
    out, err = img_subprocess.communicate()
    if img_subprocess.returncode != 0:
        print(f'Error getting frame {frame_idx}')
        print(err)
        return
    
    # print(f'Frame {frame_idx} received')
    
    image.value = out
    # print(f'Set image for frame {frame_idx}')

# %%
import datetime

def getNearestIdx(array, value):
    return (np.abs(array - value)).argmin()

def getVideoFrameMatchingCsiPosition(csi_idx: int):
    # limit csi_idx to the range of the csi data
    csi_idx = np.clip(csi_idx, 0, csi.shape[0]-1)
    csi_ts = data.status[::input_reduction.value][csi_idx].tstamp
    print(csi_ts)

    if frame_timestamps is not None:
        frame_idx = getNearestIdx(frame_timestamps, csi_ts)
    else:
        start_time = basename(filename).split('_')[0]
        start_time = datetime.datetime.strptime(start_time, '%Y-%m-%dT%H-%M-%S-%f')

        # video_start_time = start_time + datetime.timedelta(milliseconds=660) # 0.66s delay 
        video_start_time = start_time + datetime.timedelta(milliseconds=660+180) # 0.66s delay 

        csi_dt = datetime.datetime.fromtimestamp(csi_ts/1e6)

        # video frame rate is 60 fps
        # frame_idx = (csi_dt - video_start_time).total_seconds() * 60
        frame_idx = (csi_dt - video_start_time).total_seconds() * 60.35
        max_idx = csi.shape[0] - 1 # TODO get from video
        frame_idx = np.clip(int(frame_idx), 0, max_idx)

    display_video_frame(frame_idx)
    print(frame_idx)

# %%
class Notifier():
    def __init__(self):
        self.func = []

    def register(self, func):
        self.func.append(func)

    def notify(self):
        for f in self.func:
            f()

# %%
from typing import NamedTuple

import pandas as pd

from csidata.types import Activity, CSI_Result

class SegmentListEntry:
    def __init__(self, segment_list_manager, segment_bounds: tuple[int, int], segment_label: str, segment_id: int, segment_type_options: list[tuple[str, int]]):
        self.segment_bounds = segment_bounds
        self.segment_id = segment_id
        self.segment_type = widgets.Dropdown(options=segment_type_options, value=segment_type_options[0][1], layout=widgets.Layout(width='auto'))
        self.item = widgets.HBox()
        self.id_label = widgets.Label(str(segment_id))
        self.label = widgets.Label(segment_label)
        self.segment_list_manager = segment_list_manager

        space = widgets.HTML("<span style='margin-right: 1em;'></span>")

        move_down_button = widgets.Button(description='⬇️', layout=widgets.Layout(width='auto'))
        move_up_button = widgets.Button(description='⬆️', layout=widgets.Layout(width='auto'))
        remove_button = widgets.Button(description='X', layout=widgets.Layout(width='auto'))

        remove_button.on_click(lambda _: self.segment_list_manager.removeSegment(self))
        move_down_button.on_click(lambda _: self.segment_list_manager.move_down(self))
        move_up_button.on_click(lambda _: self.segment_list_manager.move_up(self))

        self.item.children = [self.id_label, space, self.label, self.segment_type, move_down_button, move_up_button, remove_button]

    def update_id(self, new_id: int):
        self.segment_id = new_id
        self.id_label.value = str(new_id)



class Segment(NamedTuple):
    start: int
    end: int
    type: Activity
    

class SegmentListManager:
    def __init__(self, segments: list[Segment], segment_notifier: Notifier, digits_padding: int, csi_result: CSI_Result) -> None:
        self.segment_notifier = segment_notifier
        self.segment_notifier.register(self.update)
        self.segment_list_items: list[SegmentListEntry] = []
        self.segments = segments
        self.csi_result = csi_result
        self.digits_padding = digits_padding
        self.vbox = widgets.VBox(layout=widgets.Layout(width='350px', min_width='300px'))
        
    def update(self) -> None:
        def segment_equals_entry(segment_bounds: tuple[int, int], entry: SegmentListEntry) -> bool:
            return entry.segment_bounds[0] == segment_bounds[0] and entry.segment_bounds[1] == segment_bounds[1]

        if len(self.segments) == len(self.segment_list_items): # two segments have been swapped, update list items
            for idx, s in enumerate(self.segments):
                if not segment_equals_entry(s, self.segment_list_items[idx]):
                    self.segment_list_items[idx].item.close()
                    self.segment_list_items[idx] = self.createSegmentEntry(s, idx)
            
        elif len(self.segments) > len(self.segment_list_items): # segment has been added
            missing_item = [s for s in self.segments if not any(segment_equals_entry(s, e) for e in self.segment_list_items)] [0]
            self.segment_list_items.append(self.createSegmentEntry(missing_item, self.segments.index(missing_item)))

        elif len(self.segments) < len(self.segment_list_items): # segment has been removed
            excess_item = [e for e in self.segment_list_items if not any(segment_equals_entry(s, e) for s in self.segments)] [0]
            self.segment_list_items.remove(excess_item)
            excess_item.item.close()

        # self.segment_list_items = [self.createSegmentEntry(segment) for segment in self.segments]
        self.vbox.children = [e.item for e in self.segment_list_items]
        

    def createSegmentEntry(self, segment_bounds: tuple[int, int], segment_id) -> None:
        label = f"({segment_bounds[0]:>0{self.digits_padding}}, {segment_bounds[1]:>0{self.digits_padding}})"

        allowed_activities: list[Activity]
        if self.csi_result.activity:
            allowed_activities = [self.csi_result.activity]
        elif self.csi_result.sequence:
            allowed_activities = list(self.csi_result.sequence.value)
        else:
            allowed_activities = list(Activity)

        segment_type_options = [(a.name, a.value) for a in allowed_activities]

        return SegmentListEntry(self, segment_bounds, label, segment_id, segment_type_options)

    def removeSegment(self, item) -> None:
        idx = self.segment_list_items.index(item)
        self.segments.pop(idx)
        self.segment_notifier.notify()

    def move_up(self, item) -> None:
        idx = self.segment_list_items.index(item)
        if idx > 0:
            self.segments[idx], self.segments[idx - 1] = self.segments[idx - 1], self.segments[idx]
            self.segment_list_items[idx], self.segment_list_items[idx - 1] = self.segment_list_items[idx - 1], self.segment_list_items[idx]
            self.segment_list_items[idx].update_id(idx)
            self.segment_list_items[idx - 1].update_id(idx - 1)
            self.segment_notifier.notify()

    
    def move_down(self, item) -> None:
        idx = self.segment_list_items.index(item)
        if idx < len(self.segments) - 1:
            self.segments[idx], self.segments[idx + 1] = self.segments[idx + 1], self.segments[idx]
            self.segment_list_items[idx], self.segment_list_items[idx + 1] = self.segment_list_items[idx + 1], self.segment_list_items[idx]
            self.segment_list_items[idx].update_id(idx)
            self.segment_list_items[idx + 1].update_id(idx + 1)
            self.segment_notifier.notify()

    
    def getListBox(self):
        return self.vbox
    
    def save_segments(self):
        segs = []
        for seg in self.segment_list_items:
            segs.append(Segment(seg.segment_bounds[0], seg.segment_bounds[1], Activity(seg.segment_type.value)))
        # print(segs)

        columns=['fileNumber', 'activityNumber', 'startPoint', 'endPoint', 'fileName', 'activityCategory']
        try:
            stored_seg = pd.read_csv(label_save_file)
            print(stored_seg.columns)
        except FileNotFoundError:
            stored_seg = pd.DataFrame(columns=columns)

        file_number = stored_seg['fileNumber'].max() + 1 if not stored_seg.empty else 1 # 1-based indexing
        
        recording_name = splitext(basename(filename))[0]

        # if file already has segments, delete to replace them with the current ones
        stored_seg = stored_seg[stored_seg['fileName'] != recording_name]

        added_segments_list = [(file_number, idx, s.start, s.end, recording_name, sli.segment_type.value) for idx, (s, sli) in enumerate(zip(self.segments, self.segment_list_items))]
        added_segments = pd.DataFrame(added_segments_list, columns=columns)
        print(added_segments)
        added_segments['activityNumber'] += 1 # 1-based indexing
        added_segments['activityCategory'] += 1 # 1-based indexing
        print(added_segments)

        pd.concat([stored_seg, added_segments], ignore_index=True).to_csv(label_save_file, index=False)

# %%
class CSIPlot:
    def __init__(self, csiTrace: np.ndarray, segments: list[Segment], segment_notifier: Notifier) -> None:
        self.notifier = segment_notifier
        self.notifier.register(self.redraw_segments)
        self.csiTrace = csiTrace
        self.output = widgets.Output()
        self.segment_selection_start = None
        self.cursorLine = None
        self.segmentStartLine = None

        self.segments = segments

        self.segmentSelectionSpan = None
        self.segmentSpans: list[patches.Polygon] = []
        self.segment_labels: list[plt.Text] = []

        self.margin = 0.1

        # self.background = None
        # self.ln = None

        with self.output:
            with plt.ioff():
                self.fig, self.ax = plt.subplots()
            self.fig: plt.Figure
            self.ax: plt.Axes

            self.fig.canvas.header_visible = False
            self.fig.canvas.toolbar_visible = False
            self.fig.canvas.footer_visible = False
            self.fig.canvas.capture_scroll = True
    
            (self.ln,) = self.ax.plot(csiTrace)

            self.cursorLine = self.ax.axvline(0, color='r', alpha=0.5)

            self.segmentStartLine = self.ax.axvline(0, color='g', alpha=0.5)
            self.segmentStartLine.set_visible(False)
            
            self.segmentSelectionSpan = self.ax.axvspan(0, 0, color='orange', alpha=0.2)
            self.segmentSelectionSpan.set_visible(False)
            
        self.fig.canvas.mpl_connect('scroll_event', self.handle_scroll)
            
    def start_selection(self, xpos):
        self.segment_selection_start = xpos
        self.segmentStartLine.set_xdata([xpos])
        self.segmentStartLine.set_visible(True)
        self.segmentSelectionSpan.set_xy([xpos, 0])
        self.segmentSelectionSpan.set_width(0)
        self.segmentSelectionSpan.set_visible(True)
        with self.output:
            self.ax.draw_artist(self.segmentStartLine)
            self.ax.draw_artist(self.segmentSelectionSpan)
            self.fig.canvas.draw_idle()        
    
    def end_selection(self, xpos):
        if not self.segment_selection_start:
            return

        self.segments.append(Segment(self.segment_selection_start, xpos, None))
        self.segment_selection_start = None
        self.segmentStartLine.set_visible(False)
        self.segmentSelectionSpan.set_visible(False)
        with self.output:
            self.redraw_segments()
            self.fig.canvas.draw_idle()        
        self.notifier.notify()
    
    def abort_selection(self):
        self.segment_selection_start = None
        self.segmentStartLine.set_visible(False)
        self.segmentSelectionSpan.set_visible(False)

        with self.output:
            self.fig.canvas.draw_idle()    

    def handle_plot_click(self, xpos):
        if xpos < 0 or xpos >= len(self.csiTrace):
            return
        
        if self.segment_selection_start:
            self.end_selection(xpos)
        else:
            self.start_selection(xpos)

    def draw_cursor(self,xpos):
        self.cursorLine.set_xdata([xpos])
        with self.output:
            self.fig.canvas.draw_idle()

    def draw_current_segment_selection_span(self, cursorPosition):
        if self.segment_selection_start:
            self.segmentSelectionSpan.set_xy([self.segment_selection_start, 0])
            self.segmentSelectionSpan.set_width(cursorPosition - self.segment_selection_start)
            self.ax.draw_artist(self.segmentSelectionSpan)
            with self.output:
                self.fig.canvas.draw_idle()
    def redraw_segments(self):
        for segment in self.segmentSpans:
            segment.remove()
        
        self.segmentSpans.clear()
        
        for segment in self.segments:
            self.segmentSpans.append(self.ax.axvspan(segment.start, segment.end, color='yellow', alpha=0.2))
        
        self.redraw_segment_labels()
        with self.output:
            self.fig.canvas.draw_idle()
    
    def redraw_segment_labels(self):
        for label in self.segment_labels:
            label.remove()

        self.segment_labels.clear()
        visible_yregion = self.ax.get_ylim()
        
        for idx, segment in enumerate(self.segments):
            self.segment_labels.append(self.ax.text((segment.start + segment.end)/2, visible_yregion[1], str(idx), horizontalalignment='center', verticalalignment='top'))

    def redraw(self):
        with self.output:
            self.fig.canvas.draw_idle()

    def move_cursor(self, xpos):
        global video_raw, image, cap, tmp_file
        xpos = int(xpos)
        # display_video_frame(tmp_file, xpos)
        getVideoFrameMatchingCsiPosition(xpos)

        # display_frame_mp4(cap, xpos)
        self.draw_cursor(xpos)
        self.draw_current_segment_selection_span(xpos)
        # self.fig.canvas.flush_events()

    def handle_scroll(self, event):
        if event.inaxes != self.ax: # ignore scroll event outside axis
            return
        zoom_factor = 0.1

        cur_xlim = self.ax.get_xlim()

        xdata = event.xdata

        if event.button == 'up':  # Zoom in
            new_xlim = [xdata - (xdata-cur_xlim[0])*(1-zoom_factor), xdata + (cur_xlim[1]-xdata)*(1-zoom_factor)]
            self.ax.set_xlim(new_xlim)
        elif event.button == 'down':  # Zoom out
            new_xlim = [xdata - (xdata-cur_xlim[0])*(1+zoom_factor), xdata + (cur_xlim[1]-xdata)*(1+zoom_factor)]
            self.ax.set_xlim(new_xlim)

        # limit x range to the data range to avoid out of bounds when determining min/max for this region
        x_idx_in_view = [max(round(new_xlim[0]), 0), 
                         min(round(new_xlim[1]), len(self.csiTrace))]

        new_ylim = [self.csiTrace[x_idx_in_view[0]:x_idx_in_view[1]].min(), self.csiTrace[x_idx_in_view[0]:x_idx_in_view[1]].max()]

        self.ax.set_ylim([new_ylim[0] + new_ylim[0] * self.margin, new_ylim[1] + new_ylim[1] * self.margin])

        self.redraw_segment_labels()
        self.fig.canvas.draw_idle()  # Redraw the figure to update the plot

# %%
# %matplotlib widget
segments: list[Segment] = []

segment_notifier = Notifier()
plot = CSIPlot(csiTrace, segments, segment_notifier)
segment_manager = SegmentListManager(segments, segment_notifier, len(str(csiTrace.shape[0])), data)

index_slider = widgets.IntSlider(min=0, max=csiTrace.shape[0] -1, step=10, value=0)
interactiveDings = widgets.interactive(plot.move_cursor, xpos=index_slider)

mark_button = widgets.Button(description='Mark')
unmark_button = widgets.Button(description='Unmark')
mark_button.on_click(lambda _: plot.handle_plot_click(index_slider.value))
unmark_button.on_click(lambda _: plot.abort_selection())

controls_hbox = widgets.HBox([mark_button, unmark_button])

save_button = widgets.Button(description='Save')
save_button.on_click(lambda _: segment_manager.save_segments())
# save_button.layout.width = '100%'    

def handle_segment_click(x):
    global segment_manager

    x_idx = round(x)
    plot.handle_plot_click(x_idx)

plot.fig.canvas.mpl_connect('button_press_event', lambda event: handle_segment_click(round(event.xdata)) if event.inaxes == plot.ax else None)
plot.fig.canvas.mpl_connect('motion_notify_event', lambda event: plot.move_cursor(round(event.xdata)) if event.inaxes == plot.ax else None)

image = widgets.Image()
img_width = 500
image.layout = widgets.Layout(width=f"{img_width}px", height=f"{img_width * 9/16}px", top='50%')

hbox_main_content = widgets.HBox([segment_manager.getListBox(), plot.fig.canvas, image])
hbox_main_content.layout.width = '100%'
plot.fig.canvas.layout.width = 'auto'

display(hbox_main_content)

display(controls_hbox)
display(save_button)

input_rx = widgets.BoundedIntText(description='rx', value=0, min=0, max=csi.shape[1]-1)
input_tx = widgets.BoundedIntText(description='tx', value=0, min=0, max=csi.shape[2]-1)
input_sc = widgets.BoundedIntText(description='sc', value=0, min=0, max=csi.shape[3]-1)
input_reduction = widgets.BoundedIntText(description='red', value=20, min=1, max=csi.shape[0])
confirm_button = widgets.Button(description='Confirm')

csi_selection = widgets.HBox([input_rx, input_tx, input_sc, input_reduction, confirm_button], layout=widgets.Layout(width='auto'))

def on_confirm_button_clicked(_):
    global csiTrace
    print(f'rx: {input_rx.value}, tx: {input_tx.value}, sc: {input_sc.value}, red: {input_reduction.value}')
    csiTrace = csi[::input_reduction.value, input_rx.value, input_tx.value, input_sc.value]

    plot.ln.remove()

    plot.csiTrace = csiTrace
    # plot.ax.clear()
    (plot.ln,) = plot.ax.plot(csiTrace)
    plot.redraw()
    plot.redraw_segments()
    plot.redraw_segment_labels()

confirm_button.on_click(on_confirm_button_clicked)

display(csi_selection)

filename_stem = splitext(basename(filename))[0]

video_path = f"record/prod_data/video/user1/{filename_stem}.mp4"
tmp_folder = "recordings/tmp"
tmp_file = f"{tmp_folder}/{filename_stem}.yuv"

if exists(splitext(video_path)[0] + '.txt'):
    with open(splitext(video_path)[0] + '.txt') as f:
            frames_ts = f.read().splitlines()[1:] # skip first line as it is a comment
            frames_ts = map(int, frames_ts)
    frame_timestamps = np.array(list(frames_ts))
    frame_timestamps = frame_timestamps * 1e3 # convert from ms to us presicion to match csi data
else:
    frame_timestamps = None

# check if tmp video file exists
if not exists(tmp_file):
    # convert video to yuv format
    video_raw =  subprocess.run(f"ffmpeg -y -v error -i {video_path} -f rawvideo -pix_fmt yuv422p -framerate 60 {tmp_file}".split(), stdout=subprocess.PIPE, check=True)

getVideoFrameMatchingCsiPosition(0)
# Out:
# HBox(children=(VBox(layout=Layout(min_width='300px', width='350px')), Canvas(capture_scroll=True, footer_visib…
# HBox(children=(Button(description='Mark', style=ButtonStyle()), Button(description='Unmark', style=ButtonStyle…
# Button(description='Save', style=ButtonStyle())
# HBox(children=(BoundedIntText(value=0, description='rx', max=2), BoundedIntText(value=0, description='tx', max…
# 1728661987995028
# FFMPEG get frame 0
# 0
# 1728661987995028
# Frame already displayed
# 0
# 1728661990270019
# 101
# FFMPEG get frame 101
# 1728661997532780
# Stopping previous subprocess
# 540
# FFMPEG get frame 540
# Error getting frame 101
# b''
# 1728662003736749
# Stopping previous subprocess
# 914
# FFMPEG get frame 914
# 1728662005923017
# Stopping previous subprocess
# 1046
# FFMPEG get frame 1046
# Error getting frame 540
# b''
# Error getting frame 914
# b''
# 1728662007254833
# Stopping previous subprocess
# 1127
# FFMPEG get frame 1127
# Error getting frame 1046
# b''
# 1728662006989504
# Stopping previous subprocess
# 1110
# FFMPEG get frame 1110
# 1728662006584239
# Stopping previous subprocess
# 1086
# FFMPEG get frame 1086
# Error getting frame 1110
# b''
# Error getting frame 1127
# b''
# 1728662005923017
# Stopping previous subprocess
# 1046
# FFMPEG get frame 1046
# Error getting frame 1086
# b''
# FFMPEG get frame 985
# 1728662004914931
# Stopping previous subprocess
# 985
# Error getting frame 1046
# b''
# 1728662004657468
# Stopping previous subprocess
# 970
# FFMPEG get frame 970
# Error getting frame 985
# b''
# 1728662004396797
# Stopping previous subprocess
# 954
# FFMPEG get frame 954
# Error getting frame 970
# b''
# FFMPEG get frame 906
# 1728662003602062
# Stopping previous subprocess
# 906
# Error getting frame 954
# b''
# FFMPEG get frame 763
# 1728662001226529
# Stopping previous subprocess
# 763
# Error getting frame 906
# b''
# 1728661998730076
# Stopping previous subprocess
# 612
# FFMPEG get frame 612
# Error getting frame 763
# b''
# 1728661996105107
# Stopping previous subprocess
# 454
# FFMPEG get frame 454
# Error getting frame 612
# b''
# FFMPEG get frame 0
# 1728661987995028
# Stopping previous subprocess
# 0
# Error getting frame 454
# b''
# 1728661987995028
# Frame already displayed
# 0
# 1728661987995028
# Frame already displayed
# 0
# 1728661987995028
# Frame already displayed
# 0
# 1728662001885015
# 802
# FFMPEG get frame 802
# 1728662001091140
# Stopping previous subprocess
# 755
# FFMPEG get frame 755
# Error getting frame 802
# b''
# FFMPEG get frame 707
# 1728662000308177
# Stopping previous subprocess
# 707
# Error getting frame 755
# b''
# 1728661999767223
# Stopping previous subprocess
# 675
# FFMPEG get frame 675
# 1728661999631338
# Stopping previous subprocess
# 666
# FFMPEG get frame 666
# Error getting frame 707
# b''
# Error getting frame 675
# b''
# 1728662000308177
# Stopping previous subprocess
# 707
# FFMPEG get frame 707
# Error getting frame 666
# b''
# 1728662000578490
# Stopping previous subprocess
# 724
# FFMPEG get frame 724
# 1728662002405472
# Stopping previous subprocess
# 834
# FFMPEG get frame 834
# Error getting frame 707
# b''
# Error getting frame 724
# b''
# 1728662004657468
# Stopping previous subprocess
# 970
# FFMPEG get frame 970
# 1728662014369115
# Stopping previous subprocess
# 1556
# FFMPEG get frame 1556
# Error getting frame 970
# b''
# Error getting frame 834
# b''
# 1728662022495701
# Stopping previous subprocess
# 2046
# FFMPEG get frame 2046
# Error getting frame 1556
# b''
# 1728662030449112
# Stopping previous subprocess
# 2526
# FFMPEG get frame 2526
# Error getting frame 2046
# b''
# 1728662034710770
# Stopping previous subprocess
# 2783
# FFMPEG get frame 2783
# Error getting frame 2526
# b''
# FFMPEG get frame 3086
# 1728662039721870
# Stopping previous subprocess
# 3086
# Error getting frame 2783
# b''
# 1728662040090418
# Stopping previous subprocess
# 3108
# FFMPEG get frame 3108
# Error getting frame 3086
# b''
# 1728662041289875
# Stopping previous subprocess
# 3181
# FFMPEG get frame 3181
# Error getting frame 3108
# b''
# FFMPEG get frame 3227
# 1728662042057781
# Stopping previous subprocess
# 3227
# Error getting frame 3181
# b''
# 1728662044078745
# Stopping previous subprocess
# 3349
# FFMPEG get frame 3349
# Error getting frame 3227
# b''
# FFMPEG get frame 3410
# 1728662045092381
# Stopping previous subprocess
# 3410
# Error getting frame 3349
# b''
# FFMPEG get frame 3418
# 1728662045218933
# Stopping previous subprocess
# 3418
# Error getting frame 3410
# b''
# FFMPEG get frame 3471
# 1728662046106113
# Stopping previous subprocess
# 3471
# Error getting frame 3418
# b''
# 1728662046106113
# Same frame being requested, wait for existing thread to finish
# 3471
# 1728662046592432
# Stopping previous subprocess
# 3501
# FFMPEG get frame 3501
# Error getting frame 3471
# b''
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/ipympl/backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:464, in FigureManagerWebAgg.handle_json(self, content)
#     463 def handle_json(self, content):
# --> 464     self.canvas.handle_event(content)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:303, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     299     MouseEvent('scroll_event', self, x, y, step=event['step'],
#     300                modifiers=modifiers, guiEvent=guiEvent)._process()
#     301 elif e_type == 'motion_notify':
#     302     MouseEvent(e_type + '_event', self, x, y,
# --> 303                modifiers=modifiers, guiEvent=guiEvent)._process()
#     304 elif e_type in ['figure_enter', 'figure_leave']:
#     305     LocationEvent(e_type + '_event', self, x, y,
#     306                   modifiers=modifiers, guiEvent=guiEvent)._process()
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backend_bases.py:1231, in Event._process(self)
#    1229 def _process(self):
#    1230     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1231     self.canvas.callbacks.process(self.name, self)
#    1232     self._guiEvent_deleted = True
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# Cell In[11], line 29, in <lambda>(event)
#      26     plot.handle_plot_click(x_idx)
#      28 plot.fig.canvas.mpl_connect('button_press_event', lambda event: handle_segment_click(round(event.xdata)) if event.inaxes == plot.ax else None)
# ---> 29 plot.fig.canvas.mpl_connect('motion_notify_event', lambda event: plot.move_cursor(round(event.xdata)) if event.inaxes == plot.ax else None)
#      31 image = widgets.Image()
#      32 img_width = 500
#
# Cell In[10], line 138, in CSIPlot.move_cursor(self, xpos)
#     136 xpos = int(xpos)
#     137 # display_video_frame(tmp_file, xpos)
# --> 138 getVideoFrameMatchingCsiPosition(xpos)
#     140 # display_frame_mp4(cap, xpos)
#     141 self.draw_cursor(xpos)
#
# Cell In[6], line 9, in getVideoFrameMatchingCsiPosition(csi_idx)
#       6 def getVideoFrameMatchingCsiPosition(csi_idx: int):
#       7     # limit csi_idx to the range of the csi data
#       8     csi_idx = np.clip(csi_idx, 0, csi.shape[0]-1)
# ----> 9     csi_ts = data.status[::input_reduction.value][csi_idx].tstamp
#      10     print(csi_ts)
#      12     if frame_timestamps is not None:
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/ipympl/backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:464, in FigureManagerWebAgg.handle_json(self, content)
#     463 def handle_json(self, content):
# --> 464     self.canvas.handle_event(content)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:303, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     299     MouseEvent('scroll_event', self, x, y, step=event['step'],
#     300                modifiers=modifiers, guiEvent=guiEvent)._process()
#     301 elif e_type == 'motion_notify':
#     302     MouseEvent(e_type + '_event', self, x, y,
# --> 303                modifiers=modifiers, guiEvent=guiEvent)._process()
#     304 elif e_type in ['figure_enter', 'figure_leave']:
#     305     LocationEvent(e_type + '_event', self, x, y,
#     306                   modifiers=modifiers, guiEvent=guiEvent)._process()
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backend_bases.py:1231, in Event._process(self)
#    1229 def _process(self):
#    1230     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1231     self.canvas.callbacks.process(self.name, self)
#    1232     self._guiEvent_deleted = True
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# Cell In[11], line 29, in <lambda>(event)
#      26     plot.handle_plot_click(x_idx)
#      28 plot.fig.canvas.mpl_connect('button_press_event', lambda event: handle_segment_click(round(event.xdata)) if event.inaxes == plot.ax else None)
# ---> 29 plot.fig.canvas.mpl_connect('motion_notify_event', lambda event: plot.move_cursor(round(event.xdata)) if event.inaxes == plot.ax else None)
#      31 image = widgets.Image()
#      32 img_width = 500
#
# Cell In[10], line 138, in CSIPlot.move_cursor(self, xpos)
#     136 xpos = int(xpos)
#     137 # display_video_frame(tmp_file, xpos)
# --> 138 getVideoFrameMatchingCsiPosition(xpos)
#     140 # display_frame_mp4(cap, xpos)
#     141 self.draw_cursor(xpos)
#
# Cell In[6], line 9, in getVideoFrameMatchingCsiPosition(csi_idx)
#       6 def getVideoFrameMatchingCsiPosition(csi_idx: int):
#       7     # limit csi_idx to the range of the csi data
#       8     csi_idx = np.clip(csi_idx, 0, csi.shape[0]-1)
# ----> 9     csi_ts = data.status[::input_reduction.value][csi_idx].tstamp
#      10     print(csi_ts)
#      12     if frame_timestamps is not None:
#
# IndexError: list index out of range
# 1728662031898111
# 2614
# FFMPEG get frame 2614
# 1728662031570216
# Stopping previous subprocess
# 2594
# FFMPEG get frame 2594
# Error getting frame 2614
# b''
# 1728662031247733
# Stopping previous subprocess
# 2574
# FFMPEG get frame 2574
# Error getting frame 2594
# b''
# 1728662028466804
# Stopping previous subprocess
# 2407
# FFMPEG get frame 2407
# Error getting frame 2574
# b''
# FFMPEG get frame 2254
# 1728662025931170
# Stopping previous subprocess
# 2254
# Error getting frame 2407
# b''
# 1728662021597019
# Stopping previous subprocess
# 1992
# FFMPEG get frame 1992
# Error getting frame 2254
# b''
# 1728662018387467
# Stopping previous subprocess
# 1798
# FFMPEG get frame 1798
# Error getting frame 1992
# b''
# FFMPEG get frame 1691
# 1728662016615257
# Stopping previous subprocess
# 1691
# Error getting frame 1798
# b''
# 1728662016169597
# Stopping previous subprocess
# 1665
# FFMPEG get frame 1665
# Error getting frame 1691
# b''
# 1728662016169597
# Same frame being requested, wait for existing thread to finish
# 1665
# 1728662015944514
# Stopping previous subprocess
# 1651
# FFMPEG get frame 1651
# Error getting frame 1665
# b''
# FFMPEG get frame 1591
# 1728662014957944
# Stopping previous subprocess
# 1591
# Error getting frame 1651
# b''
# 1728662014391047
# Stopping previous subprocess
# 1557
# FFMPEG get frame 1557
# Error getting frame 1591
# b''
# 1728662012855010
# Stopping previous subprocess
# 1464
# FFMPEG get frame 1464
# Error getting frame 1557
# b''
# 1728662011412821
# Stopping previous subprocess
# 1377
# FFMPEG get frame 1377
# Error getting frame 1464
# b''
# 1728662010320637
# Stopping previous subprocess
# 1312
# FFMPEG get frame 1312
# Error getting frame 1377
# b''
# 1728662009438468
# Stopping previous subprocess
# 1258
# FFMPEG get frame 1258
# Error getting frame 1312
# b''
# 1728662008917347
# Stopping previous subprocess
# 1227
# FFMPEG get frame 1227
# Error getting frame 1258
# b''
# FFMPEG get frame 1193
# 1728662008354212
# Stopping previous subprocess
# 1193
# Error getting frame 1227
# b''
# FFMPEG get frame 1112
# 1728662007010330
# Stopping previous subprocess
# 1112
# Error getting frame 1193
# b''
# 1728662006694573
# Stopping previous subprocess
# 1093
# FFMPEG get frame 1093
# Error getting frame 1112
# b''
# 1728662006032934
# Stopping previous subprocess
# 1053
# FFMPEG get frame 1053
# Error getting frame 1093
# b''
# 1728662005602797
# Stopping previous subprocess
# 1027
# FFMPEG get frame 1027
# Error getting frame 1053
# b''
# FFMPEG get frame 1020
# 1728662005495949
# Stopping previous subprocess
# 1020
# Error getting frame 1027
# b''
# 1728662005280688
# Stopping previous subprocess
# 1007
# FFMPEG get frame 1007
# Error getting frame 1020
# b''
# 1728662005172680
# Stopping previous subprocess
# 1001
# FFMPEG get frame 1001
# Error getting frame 1007
# b''
# 1728662005172680
# Same frame being requested, wait for existing thread to finish
# 1001
# 1728662005064071
# Stopping previous subprocess
# 994
# FFMPEG get frame 994
# 1728662004957411
# Stopping previous subprocess
# 988
# FFMPEG get frame 988
# Error getting frame 994
# b''
# Error getting frame 1001
# b''
# 1728662004850434
# 981
# FFMPEG get frame 981
# 1728662004957411
# Stopping previous subprocess
# 988
# FFMPEG get frame 988
# Error getting frame 981
# b''
# FFMPEG get frame 1027
# 1728662005602797
# Stopping previous subprocess
# 1027
# Error getting frame 988
# b''
# 1728662006694573
# Stopping previous subprocess
# 1093
# FFMPEG get frame 1093
# Error getting frame 1027
# b''
# FFMPEG get frame 1105
# 1728662006897920
# Stopping previous subprocess
# 1105
# Error getting frame 1093
# b''
# 1728662009330677
# Stopping previous subprocess
# 1252
# FFMPEG get frame 1252
# Error getting frame 1105
# b''
# FFMPEG get frame 1318
# 1728662010429571
# Stopping previous subprocess
# 1318
# Error getting frame 1252
# b''
# 1728662011102616
# Stopping previous subprocess
# 1359
# FFMPEG get frame 1359
# Error getting frame 1318
# b''
# 1728662011956110
# Stopping previous subprocess
# 1410
# FFMPEG get frame 1410
# 1728662012516954
# Stopping previous subprocess
# 1444
# FFMPEG get frame 1444
# Error getting frame 1410
# b''
# Error getting frame 1359
# b''
# 1728662013385529
# Stopping previous subprocess
# 1496
# FFMPEG get frame 1496
# Error getting frame 1444
# b''
# FFMPEG get frame 1523
# 1728662013827443
# Stopping previous subprocess
# 1523
# Error getting frame 1496
# b''
# 1728662014503565
# Stopping previous subprocess
# 1564
# FFMPEG get frame 1564
# Error getting frame 1523
# b''
# 1728662014731171
# Stopping previous subprocess
# 1578
# FFMPEG get frame 1578
# Error getting frame 1564
# b''
# FFMPEG get frame 1605
# 1728662015183675
# Stopping previous subprocess
# 1605
# Error getting frame 1578
# b''
# 1728662015297381
# Stopping previous subprocess
# 1612
# FFMPEG get frame 1612
# Error getting frame 1605
# b''
# 1728662015410238
# 1619
# FFMPEG get frame 1619
# 1728662015944514
# Stopping previous subprocess
# 1651
# FFMPEG get frame 1651
# Error getting frame 1619
# b''
# 1728662016727408
# Stopping previous subprocess
# 1698
# FFMPEG get frame 1698
# Error getting frame 1651
# b''
# FFMPEG get frame 1739
# 1728662017405780
# Stopping previous subprocess
# 1739
# Error getting frame 1698
# b''
# 1728662017516275
# Stopping previous subprocess
# 1746
# FFMPEG get frame 1746
# Error getting frame 1739
# b''
# 1728662017627677
# 1753
# FFMPEG get frame 1753
# 1728662018163396
# Stopping previous subprocess
# 1785
# FFMPEG get frame 1785
# Error getting frame 1753
# b''
# 1728662018496282
# Stopping previous subprocess
# 1805
# FFMPEG get frame 1805
# Error getting frame 1785
# b''
# FFMPEG get frame 1871
# 1728662019591037
# Stopping previous subprocess
# 1871
# Error getting frame 1805
# b''
# FFMPEG get frame 1917
# 1728662020356539
# Stopping previous subprocess
# 1917
# Error getting frame 1871
# b''
# 1728662021369144
# Stopping previous subprocess
# 1978
# FFMPEG get frame 1978
# Error getting frame 1917
# b''
# FFMPEG get frame 2025
# 1728662022135358
# Stopping previous subprocess
# 2025
# Error getting frame 1978
# b''
# FFMPEG get frame 2045
# 1728662022473104
# Stopping previous subprocess
# 2045
# Error getting frame 2025
# b''
# 1728662023600305
# Stopping previous subprocess
# 2113
# FFMPEG get frame 2113
# Error getting frame 2045
# b''
# FFMPEG get frame 2120
# 1728662023713171
# Stopping previous subprocess
# 2120
# Error getting frame 2113
# b''
# 1728662023713171
# Frame already displayed
# 2120
# 1728662024151926
# 2146
# FFMPEG get frame 2146
# 1728662025087495
# Stopping previous subprocess
# 2203
# FFMPEG get frame 2203
# 1728662026332636
# Stopping previous subprocess
# 2278
# FFMPEG get frame 2278
# Error getting frame 2146
# b''
# Error getting frame 2203
# b''
# 1728662026981752
# Stopping previous subprocess
# 2317
# FFMPEG get frame 2317
# Error getting frame 2278
# b''
# FFMPEG get frame 2375
# 1728662027946916
# Stopping previous subprocess
# 2375
# Error getting frame 2317
# b''
# 1728662028053524
# Stopping previous subprocess
# 2382
# FFMPEG get frame 2382
# Error getting frame 2375
# b''
# FFMPEG get frame 2439
# 1728662029009313
# Stopping previous subprocess
# 2439
# Error getting frame 2382
# b''
# FFMPEG get frame 2452
# 1728662029222828
# Stopping previous subprocess
# 2452
# Error getting frame 2439
# b''
# 1728662029437995
# Stopping previous subprocess
# 2465
# FFMPEG get frame 2465
# Error getting frame 2452
# b''
# 1728662029542596
# Stopping previous subprocess
# 2472
# FFMPEG get frame 2472
# Error getting frame 2465
# b''
# FFMPEG get frame 2485
# 1728662029758649
# Stopping previous subprocess
# 2485
# 1728662029865253
# Stopping previous subprocess
# 2491
# FFMPEG get frame 2491
# Error getting frame 2472
# b''
# 1728662030079290
# Stopping previous subprocess
# 2504
# FFMPEG get frame 2504
# Error getting frame 2485
# b''
# 1728662030922411
# Stopping previous subprocess
# 2555
# FFMPEG get frame 2555
# 1728662031247733
# Stopping previous subprocess
# 2574
# FFMPEG get frame 2574
# Error getting frame 2491
# b''
# 1728662032112505
# Stopping previous subprocess
# 2627
# FFMPEG get frame 2627
# Error getting frame 2574
# b''
# 1728662032220904
# Stopping previous subprocess
# 2633
# FFMPEG get frame 2633
# Error getting frame 2627
# b''
# Error getting frame 2504
# b''
# Error getting frame 2555
# b''
# 1728662032112505
# 2627
# FFMPEG get frame 2627
# 1728662032006376
# Stopping previous subprocess
# 2620
# FFMPEG get frame 2620
# Error getting frame 2627
# b''
# 1728662032112505
# Stopping previous subprocess
# 2627
# FFMPEG get frame 2627
# Error getting frame 2620
# b''
# 1728662032112505
# Same frame being requested, wait for existing thread to finish
# 2627
# 1728662032006376
# Stopping previous subprocess
# 2620
# FFMPEG get frame 2620
# Error getting frame 2627
# b''
# 1728662029437995
# Stopping previous subprocess
# 2465
# FFMPEG get frame 2465
# Error getting frame 2620
# b''
# FFMPEG get frame 2086
# 1728662023150917
# Stopping previous subprocess
# 2086
# Error getting frame 2465
# b''
# 1728662006250110
# Stopping previous subprocess
# 1066
# FFMPEG get frame 1066
# Error getting frame 2086
# b''
# FFMPEG get frame 624
# 1728661998926374
# Stopping previous subprocess
# 624
# Error getting frame 1066
# b''
# 1728661994679065
# 368
# FFMPEG get frame 368
# 1728661996960590
# Stopping previous subprocess
# 505
# FFMPEG get frame 505
# 1728661998817732
# Stopping previous subprocess
# 617
# FFMPEG get frame 617
# Error getting frame 505
# b''
# Error getting frame 368
# b''
# 1728661998926374
# Stopping previous subprocess
# 624
# FFMPEG get frame 624
# Error getting frame 617
# b''
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/ipympl/backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:464, in FigureManagerWebAgg.handle_json(self, content)
#     463 def handle_json(self, content):
# --> 464     self.canvas.handle_event(content)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:303, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     299     MouseEvent('scroll_event', self, x, y, step=event['step'],
#     300                modifiers=modifiers, guiEvent=guiEvent)._process()
#     301 elif e_type == 'motion_notify':
#     302     MouseEvent(e_type + '_event', self, x, y,
# --> 303                modifiers=modifiers, guiEvent=guiEvent)._process()
#     304 elif e_type in ['figure_enter', 'figure_leave']:
#     305     LocationEvent(e_type + '_event', self, x, y,
#     306                   modifiers=modifiers, guiEvent=guiEvent)._process()
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backend_bases.py:1231, in Event._process(self)
#    1229 def _process(self):
#    1230     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1231     self.canvas.callbacks.process(self.name, self)
#    1232     self._guiEvent_deleted = True
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# Cell In[11], line 29, in <lambda>(event)
#      26     plot.handle_plot_click(x_idx)
#      28 plot.fig.canvas.mpl_connect('button_press_event', lambda event: handle_segment_click(round(event.xdata)) if event.inaxes == plot.ax else None)
# ---> 29 plot.fig.canvas.mpl_connect('motion_notify_event', lambda event: plot.move_cursor(round(event.xdata)) if event.inaxes == plot.ax else None)
#      31 image = widgets.Image()
#      32 img_width = 500
#
# Cell In[10], line 138, in CSIPlot.move_cursor(self, xpos)
#     136 xpos = int(xpos)
#     137 # display_video_frame(tmp_file, xpos)
# --> 138 getVideoFrameMatchingCsiPosition(xpos)
#     140 # display_frame_mp4(cap, xpos)
#     141 self.draw_cursor(xpos)
#
# Cell In[6], line 9, in getVideoFrameMatchingCsiPosition(csi_idx)
#       6 def getVideoFrameMatchingCsiPosition(csi_idx: int):
#       7     # limit csi_idx to the range of the csi data
#       8     csi_idx = np.clip(csi_idx, 0, csi.shape[0]-1)
# ----> 9     csi_ts = data.status[::input_reduction.value][csi_idx].tstamp
#      10     print(csi_ts)
#      12     if frame_timestamps is not None:
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/ipympl/backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:464, in FigureManagerWebAgg.handle_json(self, content)
#     463 def handle_json(self, content):
# --> 464     self.canvas.handle_event(content)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:303, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     299     MouseEvent('scroll_event', self, x, y, step=event['step'],
#     300                modifiers=modifiers, guiEvent=guiEvent)._process()
#     301 elif e_type == 'motion_notify':
#     302     MouseEvent(e_type + '_event', self, x, y,
# --> 303                modifiers=modifiers, guiEvent=guiEvent)._process()
#     304 elif e_type in ['figure_enter', 'figure_leave']:
#     305     LocationEvent(e_type + '_event', self, x, y,
#     306                   modifiers=modifiers, guiEvent=guiEvent)._process()
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backend_bases.py:1231, in Event._process(self)
#    1229 def _process(self):
#    1230     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1231     self.canvas.callbacks.process(self.name, self)
#    1232     self._guiEvent_deleted = True
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# Cell In[11], line 29, in <lambda>(event)
#      26     plot.handle_plot_click(x_idx)
#      28 plot.fig.canvas.mpl_connect('button_press_event', lambda event: handle_segment_click(round(event.xdata)) if event.inaxes == plot.ax else None)
# ---> 29 plot.fig.canvas.mpl_connect('motion_notify_event', lambda event: plot.move_cursor(round(event.xdata)) if event.inaxes == plot.ax else None)
#      31 image = widgets.Image()
#      32 img_width = 500
#
# Cell In[10], line 138, in CSIPlot.move_cursor(self, xpos)
#     136 xpos = int(xpos)
#     137 # display_video_frame(tmp_file, xpos)
# --> 138 getVideoFrameMatchingCsiPosition(xpos)
#     140 # display_frame_mp4(cap, xpos)
#     141 self.draw_cursor(xpos)
#
# Cell In[6], line 9, in getVideoFrameMatchingCsiPosition(csi_idx)
#       6 def getVideoFrameMatchingCsiPosition(csi_idx: int):
#       7     # limit csi_idx to the range of the csi data
#       8     csi_idx = np.clip(csi_idx, 0, csi.shape[0]-1)
# ----> 9     csi_ts = data.status[::input_reduction.value][csi_idx].tstamp
#      10     print(csi_ts)
#      12     if frame_timestamps is not None:
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/ipympl/backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:464, in FigureManagerWebAgg.handle_json(self, content)
#     463 def handle_json(self, content):
# --> 464     self.canvas.handle_event(content)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:303, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     299     MouseEvent('scroll_event', self, x, y, step=event['step'],
#     300                modifiers=modifiers, guiEvent=guiEvent)._process()
#     301 elif e_type == 'motion_notify':
#     302     MouseEvent(e_type + '_event', self, x, y,
# --> 303                modifiers=modifiers, guiEvent=guiEvent)._process()
#     304 elif e_type in ['figure_enter', 'figure_leave']:
#     305     LocationEvent(e_type + '_event', self, x, y,
#     306                   modifiers=modifiers, guiEvent=guiEvent)._process()
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backend_bases.py:1231, in Event._process(self)
#    1229 def _process(self):
#    1230     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1231     self.canvas.callbacks.process(self.name, self)
#    1232     self._guiEvent_deleted = True
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# Cell In[11], line 29, in <lambda>(event)
#      26     plot.handle_plot_click(x_idx)
#      28 plot.fig.canvas.mpl_connect('button_press_event', lambda event: handle_segment_click(round(event.xdata)) if event.inaxes == plot.ax else None)
# ---> 29 plot.fig.canvas.mpl_connect('motion_notify_event', lambda event: plot.move_cursor(round(event.xdata)) if event.inaxes == plot.ax else None)
#      31 image = widgets.Image()
#      32 img_width = 500
#
# Cell In[10], line 138, in CSIPlot.move_cursor(self, xpos)
#     136 xpos = int(xpos)
#     137 # display_video_frame(tmp_file, xpos)
# --> 138 getVideoFrameMatchingCsiPosition(xpos)
#     140 # display_frame_mp4(cap, xpos)
#     141 self.draw_cursor(xpos)
#
# Cell In[6], line 9, in getVideoFrameMatchingCsiPosition(csi_idx)
#       6 def getVideoFrameMatchingCsiPosition(csi_idx: int):
#       7     # limit csi_idx to the range of the csi data
#       8     csi_idx = np.clip(csi_idx, 0, csi.shape[0]-1)
# ----> 9     csi_ts = data.status[::input_reduction.value][csi_idx].tstamp
#      10     print(csi_ts)
#      12     if frame_timestamps is not None:
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/ipympl/backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:464, in FigureManagerWebAgg.handle_json(self, content)
#     463 def handle_json(self, content):
# --> 464     self.canvas.handle_event(content)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:303, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     299     MouseEvent('scroll_event', self, x, y, step=event['step'],
#     300                modifiers=modifiers, guiEvent=guiEvent)._process()
#     301 elif e_type == 'motion_notify':
#     302     MouseEvent(e_type + '_event', self, x, y,
# --> 303                modifiers=modifiers, guiEvent=guiEvent)._process()
#     304 elif e_type in ['figure_enter', 'figure_leave']:
#     305     LocationEvent(e_type + '_event', self, x, y,
#     306                   modifiers=modifiers, guiEvent=guiEvent)._process()
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backend_bases.py:1231, in Event._process(self)
#    1229 def _process(self):
#    1230     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1231     self.canvas.callbacks.process(self.name, self)
#    1232     self._guiEvent_deleted = True
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# Cell In[11], line 29, in <lambda>(event)
#      26     plot.handle_plot_click(x_idx)
#      28 plot.fig.canvas.mpl_connect('button_press_event', lambda event: handle_segment_click(round(event.xdata)) if event.inaxes == plot.ax else None)
# ---> 29 plot.fig.canvas.mpl_connect('motion_notify_event', lambda event: plot.move_cursor(round(event.xdata)) if event.inaxes == plot.ax else None)
#      31 image = widgets.Image()
#      32 img_width = 500
#
# Cell In[10], line 138, in CSIPlot.move_cursor(self, xpos)
#     136 xpos = int(xpos)
#     137 # display_video_frame(tmp_file, xpos)
# --> 138 getVideoFrameMatchingCsiPosition(xpos)
#     140 # display_frame_mp4(cap, xpos)
#     141 self.draw_cursor(xpos)
#
# Cell In[6], line 9, in getVideoFrameMatchingCsiPosition(csi_idx)
#       6 def getVideoFrameMatchingCsiPosition(csi_idx: int):
#       7     # limit csi_idx to the range of the csi data
#       8     csi_idx = np.clip(csi_idx, 0, csi.shape[0]-1)
# ----> 9     csi_ts = data.status[::input_reduction.value][csi_idx].tstamp
#      10     print(csi_ts)
#      12     if frame_timestamps is not None:
#
# IndexError: list index out of range
# 1728662019146408
# 1844
# FFMPEG get frame 1844
# 1728662001906618
# Stopping previous subprocess
# 804
# FFMPEG get frame 804
# Error getting frame 1844
# b''
# FFMPEG get frame 724
# 1728662000578490
# Stopping previous subprocess
# 724
# Error getting frame 804
# b''
# 1728661999142179
# Stopping previous subprocess
# 637
# FFMPEG get frame 637
# Error getting frame 724
# b''
# 1728661999250689
# Stopping previous subprocess
# 643
# FFMPEG get frame 643
# Error getting frame 637
# b''
# FFMPEG get frame 717
# 1728662000466509
# Stopping previous subprocess
# 717
# Error getting frame 643
# b''
# 1728662002013419
# Stopping previous subprocess
# 810
# FFMPEG get frame 810
# Error getting frame 717
# b''
# FFMPEG get frame 505
# 1728661996960590
# Stopping previous subprocess
# 505
# Error getting frame 810
# b''
# FFMPEG get frame 282
# 1728661993267139
# Stopping previous subprocess
# 282
# Error getting frame 505
# b''
# 1728662042820164
# 3273
# FFMPEG get frame 3273
# 1728662042820164
# Same frame being requested, wait for existing thread to finish
# 3273
# 1728662042820164
# Same frame being requested, wait for existing thread to finish
# 3273
# 1728662042820164
# Same frame being requested, wait for existing thread to finish
# 3273
# 1728662042820164
# Same frame being requested, wait for existing thread to finish
# 3273
# 1728662038880359
# Stopping previous subprocess
# 3035
# FFMPEG get frame 3035
# 1728662023938724
# Stopping previous subprocess
# 2133
# FFMPEG get frame 2133
# Error getting frame 3273
# b''
# Error getting frame 3035
# b''
# 1728662005602797
# Stopping previous subprocess
# 1027
# FFMPEG get frame 1027
# Error getting frame 2133
# b''
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/ipympl/backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:464, in FigureManagerWebAgg.handle_json(self, content)
#     463 def handle_json(self, content):
# --> 464     self.canvas.handle_event(content)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backends/backend_webagg_core.py:303, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     299     MouseEvent('scroll_event', self, x, y, step=event['step'],
#     300                modifiers=modifiers, guiEvent=guiEvent)._process()
#     301 elif e_type == 'motion_notify':
#     302     MouseEvent(e_type + '_event', self, x, y,
# --> 303                modifiers=modifiers, guiEvent=guiEvent)._process()
#     304 elif e_type in ['figure_enter', 'figure_leave']:
#     305     LocationEvent(e_type + '_event', self, x, y,
#     306                   modifiers=modifiers, guiEvent=guiEvent)._process()
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/backend_bases.py:1231, in Event._process(self)
#    1229 def _process(self):
#    1230     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1231     self.canvas.callbacks.process(self.name, self)
#    1232     self._guiEvent_deleted = True
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File ~/Documents/uni/BaProj/bachelorproject/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# Cell In[11], line 29, in <lambda>(event)
#      26     plot.handle_plot_click(x_idx)
#      28 plot.fig.canvas.mpl_connect('button_press_event', lambda event: handle_segment_click(round(event.xdata)) if event.inaxes == plot.ax else None)
# ---> 29 plot.fig.canvas.mpl_connect('motion_notify_event', lambda event: plot.move_cursor(round(event.xdata)) if event.inaxes == plot.ax else None)
#      31 image = widgets.Image()
#      32 img_width = 500
#
# Cell In[10], line 138, in CSIPlot.move_cursor(self, xpos)
#     136 xpos = int(xpos)
#     137 # display_video_frame(tmp_file, xpos)
# --> 138 getVideoFrameMatchingCsiPosition(xpos)
#     140 # display_frame_mp4(cap, xpos)
#     141 self.draw_cursor(xpos)
#
# Cell In[6], line 9, in getVideoFrameMatchingCsiPosition(csi_idx)
#       6 def getVideoFrameMatchingCsiPosition(csi_idx: int):
#       7     # limit csi_idx to the range of the csi data
#       8     csi_idx = np.clip(csi_idx, 0, csi.shape[0]-1)
# ----> 9     csi_ts = data.status[::input_reduction.value][csi_idx].tstamp
#      10     print(csi_ts)
#      12     if frame_timestamps is not None:
#
# IndexError: list index out of range
# 1728662032112505
# 2627
# FFMPEG get frame 2627
# 1728662031570216
# Stopping previous subprocess
# 2594
# FFMPEG get frame 2594
# Error getting frame 2627
# b''
# 1728662029437995
# Stopping previous subprocess
# 2465
# FFMPEG get frame 2465
# Error getting frame 2594
# b''
# 1728661995348105
# 408
# FFMPEG get frame 408
# 1728661995456362
# Stopping previous subprocess
# 414
# FFMPEG get frame 414
# Error getting frame 408
# b''
# 1728661995565081
# Stopping previous subprocess
# 421
# FFMPEG get frame 421
# Error getting frame 414
# b''
# 1728661996299045
# Stopping previous subprocess
# 465
# FFMPEG get frame 465
# Error getting frame 421
# b''
# 1728662033493365
# 2710
# FFMPEG get frame 2710
# 1728662030406017
# Stopping previous subprocess
# 2524
# FFMPEG get frame 2524
# Error getting frame 2710
# b''
# 1728662029328381
# Stopping previous subprocess
# 2459
# FFMPEG get frame 2459
# 1728662026248253
# Stopping previous subprocess
# 2273
# FFMPEG get frame 2273
# Error getting frame 2524
# b''
# 1728662018496282
# Stopping previous subprocess
# 1805
# FFMPEG get frame 1805
# 1728662015521733
# Stopping previous subprocess
# 1625
# Error getting frame 2273
# b''
# FFMPEG get frame 1625
# 1728662014731171
# Stopping previous subprocess
# 1578
# FFMPEG get frame 1578
# Error getting frame 1805
# b''
# 1728662014617416
# Stopping previous subprocess
# 1571
# FFMPEG get frame 1571
# Error getting frame 1578
# b''
# 1728662014617416
# Same frame being requested, wait for existing thread to finish
# 1571
# 1728662014459596
# Stopping previous subprocess
# 1561
# FFMPEG get frame 1561
# Error getting frame 1571
# b''
# 1728662014279877
# Stopping previous subprocess
# 1550
# FFMPEG get frame 1550
# Error getting frame 1561
# b''
# FFMPEG get frame 1541
# 1728662014121709
# Stopping previous subprocess
# 1541
# Error getting frame 1550
# b''
# 1728662013962328
# Stopping previous subprocess
# 1531
# FFMPEG get frame 1531
# Error getting frame 1541
# b''
# FFMPEG get frame 1511
# 1728662013627047
# Stopping previous subprocess
# 1511
# Error getting frame 1531
# b''
# 1728662012516954
# Stopping previous subprocess
# 1444
# FFMPEG get frame 1444
# Error getting frame 1511
# b''
# FFMPEG get frame 1231
# 1728662008983072
# Stopping previous subprocess
# 1231
# Error getting frame 1444
# b''
# FFMPEG get frame 854
# Error getting frame 1231
# b''
# 1728662002743239
# Stopping previous subprocess
# 854
# 1728662000823589
# Stopping previous subprocess
# 738
# FFMPEG get frame 738
# Error getting frame 854
# b''
# FFMPEG get frame 630
# 1728661999033597
# Stopping previous subprocess
# 630
# Error getting frame 738
# b''
# 1728661997598600
# Stopping previous subprocess
# 544
# FFMPEG get frame 544
# Error getting frame 630
# b''
# 1728661997441883
# Stopping previous subprocess
# 534
# FFMPEG get frame 534
# Error getting frame 544
# b''
# Error getting frame 534
# b''
# FFMPEG get frame 458
# 1728661996170332
# Stopping previous subprocess
# 458
# 1728661992355923
# Stopping previous subprocess
# FFMPEG get frame 227227
#
# Error getting frame 458
# b''
# FFMPEG get frame 37
# 1728661989205192
# Stopping previous subprocess
# 37
# 1728661987995028
# Stopping previous subprocess
# 0
# FFMPEG get frame 0
# Error getting frame 37
# b''
# Error getting frame 227
# b''
# 1728661987995028
# Same frame being requested, wait for existing thread to finish
# 0
# 1728661987995028
# Same frame being requested, wait for existing thread to finish
# 0
# 1728661987995028
# Same frame being requested, wait for existing thread to finish
# 0
# 1728661987995028
# Frame already displayed
# 0
# 1728661987995028
# Frame already displayed
# 0
# 1728661987995028
# Frame already displayed
# 0
# 1728661987995028
# Frame already displayed
# 0
# 1728661987995028
# Frame already displayed
# 0
# 1728661988971580
# 23
# FFMPEG get frame 23
# 1728661990206691
# Stopping previous subprocess
# 98
# FFMPEG get frame 98
# Error getting frame 23
# b''
# 1728661992028886
# Stopping previous subprocess
# 208
# FFMPEG get frame 208
# Error getting frame 98
# b''
# 1728661992657927
# Stopping previous subprocess
# 246
# FFMPEG get frame 246
# Error getting frame 208
# b''
# 1728661992962794
# Stopping previous subprocess
# 264
# FFMPEG get frame 264
# Error getting frame 246
# b''
# FFMPEG get frame 282
# ...
# 822
# FFMPEG get frame 822
# Error getting frame 821
# b''
# 1728662002208717
# Frame already displayed
# 822
# 1728662002274020
# 826
# FFMPEG get frame 826
# 1728662002274020
# Same frame being requested, wait for existing thread to finish
# 826
# 1728662002274020
# Same frame being requested, wait for existing thread to finish
# 826
# 1728662002295907
# Stopping previous subprocess
# 827
# FFMPEG get frame 827
# Error getting frame 826
# b''
# 1728662002344000
# Stopping previous subprocess
# 830
# FFMPEG get frame 830
# Error getting frame 827
# b''
# 1728662002344000
# Same frame being requested, wait for existing thread to finish
# 830
# 1728662002344000
# Frame already displayed
# 830
# 1728662002295907
# 827
# FFMPEG get frame 827
# 1728662002274020
# Stopping previous subprocess
# 826
# FFMPEG get frame 826
# Error getting frame 827
# b''
# 1728662002274020
# Same frame being requested, wait for existing thread to finish
# 826
# 1728662002208717
# Stopping previous subprocess
# 822
# FFMPEG get frame 822
# Error getting frame 826
# b''
# 1728662002208717
# Same frame being requested, wait for existing thread to finish
# 822
# 1728662002186959
# Stopping previous subprocess
# 821
# FFMPEG get frame 821
# Error getting frame 822
# b''
# 1728662002148235
# Stopping previous subprocess
# 818
# FFMPEG get frame 818
# Error getting frame 821
# b''
# FFMPEG get frame 815
# 1728662002099955
# Stopping previous subprocess
# 815
# Error getting frame 818
# b''
# 1728662002056509
# Stopping previous subprocess
# 813
# Error getting frame 815
# b''
# FFMPEG get frame 813
# 1728662002056509
# Same frame being requested, wait for existing thread to finish
# 813
# 1728662002034815
# 811
# FFMPEG get frame 811
# 1728662002056509
# 813
# FFMPEG get frame 813
# 1728662002056509
# Same frame being requested, wait for existing thread to finish
# 813
# 1728662002099955
# Stopping previous subprocess
# 815
# FFMPEG get frame 815
# Error getting frame 813
# b''
# 1728662002148235
# Stopping previous subprocess
# 818
# FFMPEG get frame 818
# Error getting frame 815
# b''
# 1728662002208717
# Stopping previous subprocess
# 822
# FFMPEG get frame 822
# Error getting frame 818
# b''
# 1728662002208717
# Same frame being requested, wait for existing thread to finish
# 822
# 1728662002274020
# Stopping previous subprocess
# 826
# FFMPEG get frame 826
# Error getting frame 822
# b''
# FFMPEG get frame 827
# 1728662002295907
# Stopping previous subprocess
# 827
# Error getting frame 826
# b''
# 1728662002295907
# Same frame being requested, wait for existing thread to finish
# 827
# 1728662002344000
# Stopping previous subprocess
# 830
# FFMPEG get frame 830
# Error getting frame 827
# b''
# 1728662002405472
# Stopping previous subprocess
# 834
# FFMPEG get frame 834
# Error getting frame 830
# b''
# FFMPEG get frame 835
# 1728662002427559
# Stopping previous subprocess
# 835
# Error getting frame 834
# b''
# 1728662002562015
# Stopping previous subprocess
# 843
# FFMPEG get frame 843
# Error getting frame 835
# b''
# 1728662002720475
# Stopping previous subprocess
# 853
# FFMPEG get frame 853
# Error getting frame 843
# b''
# 1728662002788562
# Stopping previous subprocess
# 857
# FFMPEG get frame 857
# Error getting frame 853
# b''
# 1728662002811259
# Stopping previous subprocess
# 858
# FFMPEG get frame 858
# Error getting frame 857
# b''
# 1728662002811259
# Same frame being requested, wait for existing thread to finish
# 858
# 1728662002834006
# Stopping previous subprocess
# 860
# FFMPEG get frame 860
# Error getting frame 858
# b''
# FFMPEG get frame 862
# 1728662002879320
# Stopping previous subprocess
# 862
# Error getting frame 860
# b''
# 1728662002947255
# Stopping previous subprocess
# 867
# FFMPEG get frame 867
# Error getting frame 862
# b''
# 1728662002947255
# Same frame being requested, wait for existing thread to finish
# 867
# 1728662002947255
# Frame already displayed
# 867
# 1728662002991925
# 869
# FFMPEG get frame 869
# 1728662002991925
# Same frame being requested, wait for existing thread to finish
# 869
# 1728662002991925
# Same frame being requested, wait for existing thread to finish
# 869
# 1728662003062358
# Stopping previous subprocess
# 873
# FFMPEG get frame 873
# Error getting frame 869
# b''
# 1728662003105250
# Stopping previous subprocess
# 876
# FFMPEG get frame 876
# Error getting frame 873
# b''
# 1728662003128071
# Stopping previous subprocess
# 877
# FFMPEG get frame 877
# Error getting frame 876
# b''
# 1728662003128071
# Same frame being requested, wait for existing thread to finish
# 877
# 1728662003128071
# Same frame being requested, wait for existing thread to finish
# 877
# 1728662003195864
# Stopping previous subprocess
# 882
# FFMPEG get frame 882
# Error getting frame 877
# b''
# 1728662003263890
# Stopping previous subprocess
# 886
# FFMPEG get frame 886
# Error getting frame 882
# b''
# 1728662003286507
# Stopping previous subprocess
# 887
# FFMPEG get frame 887
# Error getting frame 886
# b''
# 1728662003422668
# Stopping previous subprocess
# 895
# FFMPEG get frame 895
# Error getting frame 887
# b''
# 1728662003448073
# Stopping previous subprocess
# 897
# FFMPEG get frame 897
# Error getting frame 895
# b''
# 1728662003467845
# 898
# FFMPEG get frame 898
# 1728662003513167
# Stopping previous subprocess
# 901
# FFMPEG get frame 901
# Error getting frame 898
# b''
# 1728662003513167
# Same frame being requested, wait for existing thread to finish
# 901
# 1728662003535857
# 902
# FFMPEG get frame 902
# 1728662003580712
# Stopping previous subprocess
# 905
# FFMPEG get frame 905
# Error getting frame 902
# b''
# 1728662003602062
# Stopping previous subprocess
# 906
# FFMPEG get frame 906
# Error getting frame 905
# b''
# 1728662003602062
# Same frame being requested, wait for existing thread to finish
# 906
# 1728662003624638
# Stopping previous subprocess
# 907
# FFMPEG get frame 907
# Error getting frame 906
# b''
# 1728662003624638
# Same frame being requested, wait for existing thread to finish
# 907
# 1728662003624638
# Same frame being requested, wait for existing thread to finish
# 907
# 1728662003668885
# Stopping previous subprocess
# 910
# FFMPEG get frame 910
# Error getting frame 907
# b''
# 1728662003668885
# Same frame being requested, wait for existing thread to finish
# 910
# 1728662003736749
# Stopping previous subprocess
# 914
# FFMPEG get frame 914
# Error getting frame 910
# b''
# 1728662003736749
# Frame already displayed
# 914
# 1728662003759446
# 916
# FFMPEG get frame 916
# 1728662003850063
# Stopping previous subprocess
# 921
# FFMPEG get frame 921
# Error getting frame 916
# b''
# 1728662003850063
# Same frame being requested, wait for existing thread to finish
# 921
# 1728662003850063
# Same frame being requested, wait for existing thread to finish
# 921
# 1728662003895507
# Stopping previous subprocess
# 924
# FFMPEG get frame 924
# 1728662003919311
# Stopping previous subprocess
# 925
# FFMPEG get frame 925
# Error getting frame 921
# b''
# Error getting frame 924
# b''
# 1728662003919311
# Same frame being requested, wait for existing thread to finish
# 925
# 1728662003919311
# Same frame being requested, wait for existing thread to finish
# 925
# 1728662004007521
# 931
# FFMPEG get frame 931
# 1728662004051153
# Stopping previous subprocess
# 933
# FFMPEG get frame 933
# Error getting frame 931
# b''
# FFMPEG get frame 937
# 1728662004116088
# Stopping previous subprocess
# 937
# Error getting frame 933
# b''
# 1728662004136394
# Stopping previous subprocess
# 938
# FFMPEG get frame 938
# Error getting frame 937
# b''
# 1728662004136394
# Same frame being requested, wait for existing thread to finish
# 938
# 1728662004136394
# Frame already displayed
# 938
# 1728662004222490
# 944
# FFMPEG get frame 944
# 1728662004266430
# Stopping previous subprocess
# 946
# FFMPEG get frame 946
# Error getting frame 944
# b''
# 1728662004266430
# Same frame being requested, wait for existing thread to finish
# 946
# 1728662004291620
# Stopping previous subprocess
# 948
# FFMPEG get frame 948
# Error getting frame 946
# b''
# 1728662004353546
# Stopping previous subprocess
# 951
# FFMPEG get frame 951
# Error getting frame 948
# b''
# 1728662004374989
# Stopping previous subprocess
# 953
# FFMPEG get frame 953
# Error getting frame 951
# b''
# 1728662004418593
# 955
# FFMPEG get frame 955
# 1728662004418593
# Same frame being requested, wait for existing thread to finish
# 955
# 1728662004505572
# Stopping previous subprocess
# 961
# FFMPEG get frame 961
# 1728662004505572
# Same frame being requested, wait for existing thread to finish
# 961
# Error getting frame 955
# b''
# 1728662004527222
# Stopping previous subprocess
# 962
# FFMPEG get frame 962
# Error getting frame 961
# b''
# 1728662004570687
# 965
# FFMPEG get frame 965
# 1728662004374989
# Stopping previous subprocess
# 953
# FFMPEG get frame 953
# Error getting frame 965
# b''
# 1728662004266430
# Stopping previous subprocess
# 946
# FFMPEG get frame 946
# Error getting frame 953
# b''
# 1728662004007521
# Stopping previous subprocess
# 931
# FFMPEG get frame 931
# Error getting frame 946
# b''
# 1728662003624638
# Stopping previous subprocess
# 907
# FFMPEG get frame 907
# Error getting frame 931
# b''
# FFMPEG get frame 901
# 1728662003513167
# Stopping previous subprocess
# 901
# Error getting frame 907
# b''
# 1728662003422668
# Stopping previous subprocess
# 895
# FFMPEG get frame 895
# Error getting frame 901
# b''
# 1728662003309138
# Stopping previous subprocess
# 888
# FFMPEG get frame 888
# Error getting frame 895
# b''
# 1728662003286507
# Stopping previous subprocess
# 887
# FFMPEG get frame 887
# Error getting frame 888
# b''
# 1728662003263890
# Stopping previous subprocess
# 886
# FFMPEG get frame 886
# Error getting frame 887
# b''
# 1728662003195864
# Stopping previous subprocess
# 882
# FFMPEG get frame 882
# Error getting frame 886
# b''
# 1728662003128071
# Stopping previous subprocess
# 877
# FFMPEG get frame 877
# Error getting frame 882
# b''
# 1728662003128071
# Same frame being requested, wait for existing thread to finish
# 877
# 1728662003105250
# Stopping previous subprocess
# 876
# FFMPEG get frame 876
# Error getting frame 877
# b''
# FFMPEG get frame 873
# 1728662003062358
# Stopping previous subprocess
# 873
# Error getting frame 876
# b''
# 1728662002991925
# Stopping previous subprocess
# 869
# FFMPEG get frame 869
# Error getting frame 873
# b''
# 1728662002969765
# Stopping previous subprocess
# FFMPEG get frame 868
# 868
# Error getting frame 869
# b''
# 1728662002947255
# 867
# FFMPEG get frame 867
# 1728662002947255
# Same frame being requested, wait for existing thread to finish
# 867
# 1728662002879320
# Stopping previous subprocess
# 862
# FFMPEG get frame 862
# Error getting frame 867
# b''
# FFMPEG get frame 860
# 1728662002834006
# Stopping previous subprocess
# 860
# Error getting frame 862
# b''
# 1728662002811259
# Stopping previous subprocess
# 858
# FFMPEG get frame 858
# Error getting frame 860
# b''
# 1728662002788562
# Stopping previous subprocess
# 857
# FFMPEG get frame 857
# Error getting frame 858
# b''
# FFMPEG get frame 853
# 1728662002720475
# Stopping previous subprocess
# 853
# Error getting frame 857
# b''
# 1728662002720475
# Frame already displayed
# 853
# 1728662002652964
# 849
# FFMPEG get frame 849
# 1728662002584719
# Stopping previous subprocess
# 845
# FFMPEG get frame 845
# 1728662002562015
# Stopping previous subprocess
# 843
# FFMPEG get frame 843
# Error getting frame 849
# b''
# Error getting frame 845
# b''
# 1728662002517003
# Stopping previous subprocess
# 841
# FFMPEG get frame 841
# Error getting frame 843
# b''
# 1728662002494433
# Stopping previous subprocess
# 839
# FFMPEG get frame 839
# Error getting frame 841
# b''
# 1728662002449659
# Stopping previous subprocess
# FFMPEG get frame 837
# 837
# Error getting frame 839
# b''
# 1728662002427559
# 835
# FFMPEG get frame 835
# 1728662002405472
# Stopping previous subprocess
# 834
# FFMPEG get frame 834
# Error getting frame 835
# b''
# 1728662002344000
# Stopping previous subprocess
# 830
# FFMPEG get frame 830
# Error getting frame 834
# b''
# 1728662002344000
# Same frame being requested, wait for existing thread to finish
# 830
# 1728662002295907
# Stopping previous subprocess
# 827
# FFMPEG get frame 827
# Error getting frame 830
# b''
# 1728662002274020
# Stopping previous subprocess
# 826
# FFMPEG get frame 826
# Error getting frame 827
# b''
# 1728662002274020
# Same frame being requested, wait for existing thread to finish
# 826
# 1728662002274020
# Frame already displayed
# 826
# 1728662002295907
# 827
# FFMPEG get frame 827
# 1728662002427559
# Stopping previous subprocess
# 835
# FFMPEG get frame 835
# 1728662002427559
# Same frame being requested, wait for existing thread to finish
# 835
# Error getting frame 827
# b''
# 1728662002449659
# Stopping previous subprocess
# 837
# FFMPEG get frame 837
# Error getting frame 835
# b''
# 1728662002494433
# Stopping previous subprocess
# 839
# FFMPEG get frame 839
# Error getting frame 837
# b''
# 1728662002494433
# Frame already displayed
# 839
# 1728662002449659
# 837
# FFMPEG get frame 837
# 1728662002427559
# Stopping previous subprocess
# 835
# FFMPEG get frame 835
# Error getting frame 837
# b''
# 1728662002405472
# Stopping previous subprocess
# 834
# FFMPEG get frame 834
# Error getting frame 835
# b''
# 1728662002344000
# Stopping previous subprocess
# 830
# FFMPEG get frame 830
# Error getting frame 834
# b''
# 1728662002405472
# Stopping previous subprocess
# 834
# FFMPEG get frame 834
# Error getting frame 830
# b''
# FFMPEG get frame 835
# 1728662002427559
# Stopping previous subprocess
# 835
# Error getting frame 834
# b''
# 1728662002427559
# Same frame being requested, wait for existing thread to finish
# 835
# 1728662002449659
# Stopping previous subprocess
# 837
# FFMPEG get frame 837
# Error getting frame 835
# b''
# 1728662002449659
# Same frame being requested, wait for existing thread to finish
# 837
# 1728662002449659
# Same frame being requested, wait for existing thread to finish
# 837
# 1728662002344000
# Stopping previous subprocess
# 830
# FFMPEG get frame 830
# 1728662002274020
# Stopping previous subprocess
# 826
# FFMPEG get frame 826
# Error getting frame 837
# b''
# Error getting frame 830
# b''
# 1728662002208717
# Stopping previous subprocess
# 822
# FFMPEG get frame 822
# Error getting frame 826
# b''
# 1728662000511193
# 720
# FFMPEG get frame 720
# 1728662000600589
# Stopping previous subprocess
# 725
# FFMPEG get frame 725
# Error getting frame 720
# b''
# 1728662000846573
# Stopping previous subprocess
# 740
# FFMPEG get frame 740
# Error getting frame 725
# b''
# 1728662001113498
# Stopping previous subprocess
# 756
# FFMPEG get frame 756
# Error getting frame 740
# b''
# 1728662001383956
# Stopping previous subprocess
# 772
# FFMPEG get frame 772
# Error getting frame 756
# b''
# 1728662001668374
# Stopping previous subprocess
# 789
# FFMPEG get frame 789
# Error getting frame 772
# b''
# 1728662001798022
# Stopping previous subprocess
# 797
# FFMPEG get frame 797
# Error getting frame 789
# b''
# 1728662001885015
# Stopping previous subprocess
# 802
# FFMPEG get frame 802
# Error getting frame 797
# b''
# 1728662001992557
# Stopping previous subprocess
# 809
# FFMPEG get frame 809
# Error getting frame 802
# b''
# 1728662002274020
# Stopping previous subprocess
# 826
# FFMPEG get frame 826
# Error getting frame 809
# b''
# 1728662002427559
# Stopping previous subprocess
# 835
# FFMPEG get frame 835
# Error getting frame 826
# b''
# 1728662002427559
# Same frame being requested, wait for existing thread to finish
# 835
# 1728662002449659
# Stopping previous subprocess
# 837
# FFMPEG get frame 837
# Error getting frame 835
# b''
# FFMPEG get frame 839
# 1728662002494433
# Stopping previous subprocess
# 839
# Error getting frame 837
# b''
# 1728662002562015
# Stopping previous subprocess
# FFMPEG get frame 843
# 843
# Error getting frame 839
# b''
# 1728662002562015
# Same frame being requested, wait for existing thread to finish
# 843
# 1728662002584719
# 845
# FFMPEG get frame 845
# 1728662002630220
# Stopping previous subprocess
# 847
# FFMPEG get frame 847
# Error getting frame 845
# b''
# FFMPEG get frame 849
# 1728662002652964
# Stopping previous subprocess
# 849
# Error getting frame 847
# b''
# 1728662002652964
# Same frame being requested, wait for existing thread to finish
# 849
# 1728662002630220
# 847
# FFMPEG get frame 847
# 1728662002584719
# Stopping previous subprocess
# 845
# FFMPEG get frame 845
# Error getting frame 847
# b''
# 1728662002584719
# Same frame being requested, wait for existing thread to finish
# 845
# 1728662002562015
# Stopping previous subprocess
# 843
# FFMPEG get frame 843
# Error getting frame 845
# b''
# 1728662002562015
# Frame already displayed
# 843
# 1728662002517003
# 841
# FFMPEG get frame 841
# 1728662002517003
# Same frame being requested, wait for existing thread to finish
# 841
# 1728662002494433
# Stopping previous subprocess
# 839
# FFMPEG get frame 839
# Error getting frame 841
# b''
# 1728662002494433
# Same frame being requested, wait for existing thread to finish
# 839
# 1728661992617941
# 243
# FFMPEG get frame 243
# 1728661993049080
# Stopping previous subprocess
# 269
# FFMPEG get frame 269
# Error getting frame 243
# b''
# 1728661993506444
# Stopping previous subprocess
# 297
# FFMPEG get frame 297
# Error getting frame 269
# b''
# 1728661994030180
# Stopping previous subprocess
# 328
# FFMPEG get frame 328
# Error getting frame 297
# b''
# 1728661994747218
# Stopping previous subprocess
# 372
# FFMPEG get frame 372
# Error getting frame 328
# b''
