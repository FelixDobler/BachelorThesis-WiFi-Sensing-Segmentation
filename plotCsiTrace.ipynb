# %%
import pandas as pd
import seaborn as sns
import numpy as np
import joblib
import matplotlib.pyplot as plt

# %%
class CSI_Struct:
    def __init__(self, tstamp, channel, chanBW, rate, nr, nc, num_tones, noise, phyerr, rssi, rssi_0, rssi_1, rssi_2, payload_len, csi_len, buf_len):
        self.tstamp = tstamp
        self.channel = channel
        self.chanBW = chanBW
        self.rate = rate
        self.nr = nr
        self.nc = nc
        self.num_tones = num_tones
        self.noise = noise
        self.phyerr = phyerr
        self.rssi = rssi
        self.rssi_0 = rssi_0
        self.rssi_1 = rssi_1
        self.rssi_2 = rssi_2
        self.payload_len = payload_len
        self.csi_len = csi_len
        self.buf_len = buf_len

# %%
records = joblib.load('csi_recordings_local/philipp_pushups_testing_56.joblib')
len(records[0])
# Out:
# 311322

# %%
csi_mat_amp = np.array(records[1])
csi_mat_amp.shape
# Out:
# (311322, 3, 3, 56)

# %%
trace = csi_mat_amp[:,0,0,1]
sns.lineplot(data=csi_mat_amp[:,0,0,0])
plt.show()
sns.lineplot(data=csi_mat_amp[:,0,0,1])
# Out:
# <Axes: >

# %%
pd.Series(trace).rolling(2).mean().plot()
# Out:
# <Axes: >

# %%
np.any(csi_mat_amp[:,:,:,:], axis=3)
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]]])

# %%
csi_mat_amp[0][0][0]
# Out:
# array([114, 127, 132, 138, 138, 140, 141, 138, 138, 137, 133, 127, 129,
#        122, 116, 109, 102,  96,  88,  87,  77,  70,  66,  54,  53,  45,
#         41,  34,  23,  13,   9,   2,  -5, -12, -20, -27, -33, -38, -43,
#        -49, -55, -60, -70, -70, -77, -79, -85, -83, -84, -86, -78, -72,
#        -66, -60, -60, -46], dtype=int16)
