# %%
import csidata as cid
import seaborn as sns

# %%
data = cid.load('record/prod_data/csi/user1/2024-10-11T16-54-58-944612_seq-iw.raw')
data.csi.shape
# Out:
# (43873, 3, 3, 56)

# %%
# plot reduced frames for a visually promising antenna pair and subcarrier in our setup
sns.lineplot(data.csi[0:10000, 2, 1, 50])
# Out:
# <Axes: >
