# %%
import numpy as np
import h5py
import seaborn as sns

# %%
f = h5py.File('../user1/55user1_iw_1.mat','r')

data = f.get('data_')
data
# Out:
# <HDF5 dataset "data_": shape (3, 30, 6255), type "<f8">

# %%
data[0]
csi = np.array(data) # For converting to a NumPy array
sns.histplot(csi.flatten(), bins=100, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
csi.shape
# get statistics of the data
# np.mean(csi)
# np.std(csi)
# np.min(csi)
# np.max(csi)
# Out:
# (3, 30, 6255)

# %%
csiS = csi.flatten()
csiS.sort()
csiS
# Out:
# array([0.00000000e+00, 1.30338902e-06, 1.30338902e-06, ...,
#        3.29096445e+01, 3.33243285e+01, 3.41796656e+01])

# %%
# calculate the differences between values
diffs = np.diff(csiS)
diffs.sort()
uniq = np.unique(diffs)
uniq.sort()
uniq[1]
uniq.shape
roun = uniq.round(6)
roun = np.unique(roun)
np.unique_values
# Out:
# <function unique_values at 0x7f670416ae30>

# %%
1 / 8.470329472543003e-22
# Out:
# 1.1805916207174113e+21

# %%
import seaborn as sns
sns.scatterplot(roun)
# Out:
# <Axes: >
